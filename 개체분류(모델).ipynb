# %%
# from konlpy.tag import Komoran
# import jpype
# import pandas as pd

# l1=[]

# def bio(text):
#     l=[]
#     komoran = Komoran(userdic='user_dic.tsv')
# #     jpype.attachThreadToJVM()
#     k_pos=komoran.pos(text)
#     num=0

#     for i, j in k_pos:
#         num+=1
#         if i in locations:
#             li=(num,i,j,"B_location")
#         elif i in money:
#             li=(num,i,j,"B_money")
#         else:
#             li=(num,i,j,"O")
#         l.append(li)
#     l1.append(l)
#     return k_pos
  
# def dataf():
#     return pd.DataFrame(l1)

# %%
# bio()

# %%
accounts = '''
953746440
120799373 
308090030 
901399601 
854440935
111111112
222222223
'''

# %%
account=accounts.split('\n')[1:-1]
account
# Out:
# ['953746440',
#  '120799373 ',
#  '308090030 ',
#  '901399601 ',
#  '854440935',
#  '111111112',
#  '222222223']

# %%
# import numpy as np 

# a = np.random.randint(100000000,999999999,10)
# a

# %%
# for i in a:
#     print(i)

# %%
money='''
86553
61073
87484
34762
34810
52303
67127
19555
70681
21505
31674
41442
905
53869
87469
19158
13089
15470
17686
61387
15319
89214
1279
81107
7384
6731
17363
9844
27850
63165
59365
16504
23401
70080
81975
91034
47449
39240
25074
57804
24477
10848
56021
89203
33480
50726
74033
36359
68332
52178
29917
57210
10820
80875
40854
73907
45947
4375
64436
55015
57384
39137
87946
95690
84710
8893
34056
65404
42010
80136
88809
45452
13954
5598
77716
73825
10495
73123
71257
2386
92245
70743
34666
83370
95827
49850
24981
98424
97185
51246
9287
78234
21374
43739
45031
50683
57021
88278
53785
51113
51820
47546
27173
7719
97720
52003
93820
95114
85398
32708
53587
40371
12132
4552
95092
16707
27008
8943
5810
44636
54599
80325
33940
83286
24130
97347
25877
81827
73479
35370
12646
38467
25715
98929
14591
59765
19642
60293
10357
85407
33232
11946
66941
64627
12632
36225
49292
91909
79276
9040
27787
16680
80526
75972
87416
37251
5283
90962
57276
36249
95334
70203
70520
30028
63839
94836
74205
30974
12921
34218
1583
14019
68732
70292
9998
96580
13812
26400
92162
984
19474
43149
27800
54654
2853
72679
11934
47008
31040
42160
56245
86470
11220
20683
'''

# %%
# 52781
# 87547
# 35791
# 96492
# 95574
# 55049
# 25162
# 5036
# 45924
# 52843
# 24413
# 80208
# 63258
# 66792
# 89498
# 43482
# 36545
# 10268
# 442
# 45928
# 63432
# 58925
# 95147
# 32457
# 2993
# 75392
# 19180
# 60802
# 11571
# 58207
# 98933
# 13776
# 26162
# 94609
# 1676
# 2406
# 40700
# 19446
# 11362
# 65987
# 103
# 49357
# 91332
# 15154
# 19046
# 68376
# 31195
# 38843
# 38076
# 98148
# 31519
# 80270
# 36287
# 9713
# 73173
# 9455
# 10202
# 68767
# 95120
# 20994
# 80479
# 27633
# 46486
# 56322
# 90373
# 68331
# 57151
# 31394
# 7837
# 42318
# 70643
# 1722
# 76219
# 99672
# 16449
# 32854
# 66863
# 24672
# 45840
# 97822
# 57848
# 30898
# 75876
# 65144
# 86743
# 31630
# 44205
# 35635
# 42782
# 18458
# 16616
# 77733
# 33783
# 91871
# 77630
# 17181
# 23509
# 54773
# 97634
# 1731
# 37913
# 4558
# 16466
# 71732
# 48684
# 50897
# 13697
# 45959
# 12428
# 39372
# 45160
# 69566
# 6442
# 51072
# 95090
# 69342
# 61697
# 80539
# 29690
# 16190
# 60229
# 59229
# 6004
# 69573
# 4222
# 48546
# 6784
# 40799
# 27182
# 84106
# 61955
# 63254
# 56553
# 99387
# 12012
# 10652
# 16308
# 39695
# 8656
# 15970
# 84288
# 72297
# 10375
# 46495
# 78674
# 11136
# 28381
# 37705
# 31345
# 97534
# 40314
# 65809
# 1685
# 14167
# 19350
# 93061
# 75999
# 25850
# 53893
# 1801
# 42428
# 11859
# 20562
# 57216
# 89679
# 8076
# 74032
# 17845
# 33615
# 98549
# 72628
# 62589
# 17703
# 60528
# 84265
# 62476
# 82843
# 27531
# 48819
# 77603
# 28161
# 23122
# 75646
# 43652
# 34737
# 53344
# 88519
# 88899
# 49968
# 97348
# 39601
# 81444
# 22357
# 72650
# 24208
# 8439
# 33670
# 89403
# 26237
# 98497
# 20269
# 13891
# 74727
# 29632
# 87057
# 72573
# 38727
# 58743
# 36047
# 78993
# 5114
# 49010
# 92136
# 41857
# 23067
# 15187
# 68528
# 13182
# 42434
# 50056
# 84596
# 65609
# 2152
# 54751
# 13213
# 59264
# 49468
# 24854
# 87718
# 69954
# 27578
# 78307
# 68495
# 86897
# 43864
# 35725
# 22045
# 25743
# 3927
# 15676
# 38866
# 23790
# 56635
# 94326
# 87842
# 91818
# 3650
# 17452
# 92738

# %%
moneies=money.split('\n')[1:-1]

# %%
moneies
# Out:
# ['86553',
#  '61073',
#  '87484',
#  '34762',
#  '34810',
#  '52303',
#  '67127',
#  '19555',
#  '70681',
#  '21505',
#  '31674',
#  '41442',
#  '905',
#  '53869',
#  '87469',
#  '19158',
#  '13089',
#  '15470',
#  '17686',
#  '61387',
#  '15319',
#  '89214',
#  '1279',
#  '81107',
#  '7384',
#  '6731',
#  '17363',
#  '9844',
#  '27850',
#  '63165',
#  '59365',
#  '16504',
#  '23401',
#  '70080',
#  '81975',
#  '91034',
#  '47449',
#  '39240',
#  '25074',
#  '57804',
#  '24477',
#  '10848',
#  '56021',
#  '89203',
#  '33480',
#  '50726',
#  '74033',
#  '36359',
#  '68332',
#  '52178',
#  '29917',
#  '57210',
#  '10820',
#  '80875',
#  '40854',
#  '73907',
#  '45947',
#  '4375',
#  '64436',
#  '55015',
#  '57384',
#  '39137',
#  '87946',
#  '95690',
#  '84710',
#  '8893',
#  '34056',
#  '65404',
#  '42010',
#  '80136',
#  '88809',
#  '45452',
#  '13954',
#  '5598',
#  '77716',
#  '73825',
#  '10495',
#  '73123',
#  '71257',
#  '2386',
#  '92245',
#  '70743',
#  '34666',
#  '83370',
# ...

# %%
from konlpy.tag import Komoran
import jpype
import pandas as pd

l1=[]

def bio(text):
    l=[]
    komoran = Komoran(userdic='user_dic.tsv')
#     jpype.attachThreadToJVM()
    k_pos=komoran.pos(text)

    for i, j in k_pos:
        
        if len(i)==9 and j =='SN':                # 계좌
            li=(i,j,"B_account")
        elif j =='SN':                            # 금액
            li=(i,j,"B_money")
        else:
            li=(i,j,"O")
        l.append(li)
    l1.append(l)
    return l1
  
def dataf():
    return pd.DataFrame(l1)

# %%
bio('111111112로 47449원 이체하고싶어')
# Out:
# [[('111111112', 'SN', 'B_account'),
#   ('로', 'JKB', 'O'),
#   ('47449', 'SN', 'B_money'),
#   ('원', 'NNB', 'O'),
#   ('이체', 'NNG', 'O'),
#   ('하', 'XSV', 'O'),
#   ('고', 'EC', 'O'),
#   ('싶', 'VX', 'O'),
#   ('어', 'EC', 'O')]]

# %%
sentence = '''
{}에 {}원 이체하고싶어
{}에 {}원 이체할래
{}에 {}원 이체할려고
{}에 {}원 이체
{}에 {}원 이체하고싶어요
{}에 {}원 이체할려고
{}에 {}원 이체
{}에 {}원 이체진행시켜
'''

# %%
sentence = sentence[1:-1].split('\n')
sentence
# Out:
# ['{}에 {}원 이체하고싶어',
#  '{}에 {}원 이체할래',
#  '{}에 {}원 이체할려고',
#  '{}에 {}원 이체',
#  '{}에 {}원 이체하고싶어요',
#  '{}에 {}원 이체할려고',
#  '{}에 {}원 이체',
#  '{}에 {}원 이체진행시켜']

# %%
sent = []
for acc in account:
    for m in moneies:
        for a in sentence:
            sent.append(a.format(acc,m))

# %%
sent
# Out:
# ['953746440에 86553원 이체하고싶어',
#  '953746440에 86553원 이체할래',
#  '953746440에 86553원 이체할려고',
#  '953746440에 86553원 이체',
#  '953746440에 86553원 이체하고싶어요',
#  '953746440에 86553원 이체할려고',
#  '953746440에 86553원 이체',
#  '953746440에 86553원 이체진행시켜',
#  '953746440에 61073원 이체하고싶어',
#  '953746440에 61073원 이체할래',
#  '953746440에 61073원 이체할려고',
#  '953746440에 61073원 이체',
#  '953746440에 61073원 이체하고싶어요',
#  '953746440에 61073원 이체할려고',
#  '953746440에 61073원 이체',
#  '953746440에 61073원 이체진행시켜',
#  '953746440에 87484원 이체하고싶어',
#  '953746440에 87484원 이체할래',
#  '953746440에 87484원 이체할려고',
#  '953746440에 87484원 이체',
#  '953746440에 87484원 이체하고싶어요',
#  '953746440에 87484원 이체할려고',
#  '953746440에 87484원 이체',
#  '953746440에 87484원 이체진행시켜',
#  '953746440에 34762원 이체하고싶어',
#  '953746440에 34762원 이체할래',
#  '953746440에 34762원 이체할려고',
#  '953746440에 34762원 이체',
#  '953746440에 34762원 이체하고싶어요',
#  '953746440에 34762원 이체할려고',
#  '953746440에 34762원 이체',
#  '953746440에 34762원 이체진행시켜',
#  '953746440에 34810원 이체하고싶어',
# ...

# %%
df = pd.DataFrame(sent)
df.to_csv(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\ner\send.txt', index=False)

# %%
for i in sent[:100]:
    a=bio(i)

# %% [markdown]
# # --------------------------------

# %%
a = bio(i)
a

# %%
# Sample = dataf()
# Sample.to_csv(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\ner\save.csv', index = False)

# %%
# 클래스 별 레이블
self.labels = {0: "O", 1: "B_account", 2: "B_money", }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [164], in <cell line: 2>()
#       1 # 클래스 별 레이블
# ----> 2 self.labels = {0: "O", 1: "B_account", 2: "B_money", }
#
# NameError: name 'self' is not defined

# %%
a[0]
# Out:
# [('111111112', 'SN', 'B_account'),
#  ('로', 'JKB', 'O'),
#  ('47449', 'SN', 'B_money'),
#  ('원', 'NNB', 'O'),
#  ('이체', 'NNG', 'O'),
#  ('하', 'XSV', 'O'),
#  ('고', 'EC', 'O'),
#  ('싶', 'VX', 'O'),
#  ('어', 'EC', 'O')]

# %%
# ② 위에서 불러온 말뭉치 데이터에서 단어(w[1])와 BIO 태그(w[3])만 불러와 학습용 데이터셋 생성

sentences, tags = [], []
for t in a:
    tagged_sentence = []
    sentence, bio_tag = [], []
    for w in t:
        tagged_sentence.append((w[0], w[2]))
        sentence.append(w[0])
        bio_tag.append(w[2])
    
    sentences.append(sentence)
    tags.append(bio_tag)

# %%
sentences[:5]
# Out:
# [['111111112', '로', '47449', '원', '이체', '하', '고', '싶', '어'],
#  ['953746440', '에', '86553', '원', '이체', '하', '고', '싶', '어'],
#  ['953746440', '에', '86553', '원', '이체', '하', 'ㄹ래'],
#  ['953746440', '에', '86553', '원', '이체', '하', 'ㄹ려고'],
#  ['953746440', '에', '86553', '원', '이체']]

# %%
tags[:5]
# Out:
# [['B_account', 'O', 'B_money', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B_account', 'O', 'B_money', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B_account', 'O', 'B_money', 'O', 'O', 'O', 'O'],
#  ['B_account', 'O', 'B_money', 'O', 'O', 'O', 'O'],
#  ['B_account', 'O', 'B_money', 'O', 'O']]

# %%
print("샘플 크기 : \n", len(sentences))
print("0번 째 샘플 단어 시퀀스 : \n", sentences[1])
print("0번 째 샘플 bio 태그 : \n", tags[1])
print("샘플 단어 시퀀스 최대 길이 :", max(len(l) for l in sentences))
print("샘플 단어 시퀀스 평균 길이 :", (sum(map(len, sentences))/len(sentences)))
# 평균의 경우. 나중에 시퀀스 벡터 크기 설정시 참조됨.
# Out:
# 샘플 크기 :
#  105
# 0번 째 샘플 단어 시퀀스 :
#  ['953746440', '에', '86553', '원', '이체', '하', '고', '싶', '어']
# 0번 째 샘플 bio 태그 :
#  ['B_account', 'O', 'B_money', 'O', 'O', 'O', 'O', 'O', 'O']
# 샘플 단어 시퀀스 최대 길이 : 9
# 샘플 단어 시퀀스 평균 길이 : 7.133333333333334

# %% [markdown]
# # =============================

# %%
from tensorflow.keras import preprocessing
sent_tokenizer = preprocessing.text.Tokenizer(oov_token='OOV')   # 이를 지정하면 1번 인덱스가 'OOV' 가 됨.
# oov : out of vocabulary
#      미리 인덱싱 되어 있지 않은 단어들은 "<OOV>" 로 인덱싱 됩니다
sent_tokenizer.fit_on_texts(sentences)

# %%
sent_tokenizer.word_index
# Out:
# {'OOV': 1,
#  '원': 2,
#  '이체': 3,
#  '953746440': 4,
#  '에': 5,
#  '하': 6,
#  '고': 7,
#  '싶': 8,
#  '어': 9,
#  'ㄹ려고': 10,
#  'ㄹ래': 11,
#  '86553': 12,
#  '어요': 13,
#  '진행': 14,
#  '시키': 15,
#  '61073': 16,
#  '87484': 17,
#  '34762': 18,
#  '34810': 19,
#  '52303': 20,
#  '67127': 21,
#  '19555': 22,
#  '70681': 23,
#  '21505': 24,
#  '31674': 25,
#  '41442': 26,
#  '905': 27,
#  '111111112': 28,
#  '로': 29,
#  '47449': 30}

# %%
# ③ 토크나이저 정의
# 단어 시퀀스의 경우 Preprocess 객체에서 생성하기 때문에 예제에서는 BIO 태그용 Tokenizer 객체 생성
tag_tokenizer = preprocessing.text.Tokenizer(lower=False) # 태그 정보는 lower=False 소문자로 변환하지 않는다.
tag_tokenizer.fit_on_texts(tags)  # 나중에 texts_to_sequences() 등을 수행하기 전에 꼭
tag_tokenizer.word_index
# Out:
# {'O': 1, 'B_account': 2, 'B_money': 3}

# %% [markdown]
# ### ==================================

# %%
import os
from chatbot.utils.Preprocess import Preprocess
p = Preprocess(word2index_dic=os.path.join(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\ner', 'sota3.bin'),
               userdic=os.path.join(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\ner', 'user_dic.tsv'))

# %% [markdown]
# # ======================

# %%
tag_tokenizer.word_index
# Out:
# {'O': 1, 'B_account': 2, 'B_money': 3}

# %%
# 단어사전 및 태그 사전 크기
vocab_size = len(p.word_index) + 1
tag_size = len(tag_tokenizer.word_index) + 1
print("BIO 태그 사전 크기 :", tag_size)
print("단어 사전 크기 :", vocab_size)
# Out:
# BIO 태그 사전 크기 : 4
# 단어 사전 크기 : 4186

# %%
# ④ 학습용 단어 시퀀스 생성
x_train = [p.get_wordidx_sequence(sent) for sent in sentences]
# x_train= sent_tokenizer.texts_to_sequences(sentences)
y_train = tag_tokenizer.texts_to_sequences(tags)

index_to_ner = tag_tokenizer.index_word # 시퀀스 인덱스를 NER로 변환 하기 위해 사용
index_to_ner[0] = 'PAD'    # 좀있다 패딩을 넣어야 하기때문에 추가함

# %%
len(x_train)
# Out:
# 105

# %%
x_train[:20]
# Out:
# [[230, 51, 1, 130, 116, 2, 7, 15, 8],
#  [1, 26, 613, 130, 116, 2, 7, 15, 8],
#  [1, 26, 613, 130, 116, 2, 53],
#  [1, 26, 613, 130, 116, 2, 96],
#  [1, 26, 613, 130, 116],
#  [1, 26, 613, 130, 116, 2, 7, 15, 8],
#  [1, 26, 613, 130, 116, 2, 53],
#  [1, 26, 613, 130, 116, 2, 96],
#  [1, 26, 613, 130, 116],
#  [1, 26, 613, 130, 116, 2, 7, 15, 32],
#  [1, 26, 613, 130, 116, 2, 96],
#  [1, 26, 613, 130, 116],
#  [1, 26, 613, 130, 116, 216, 374, 8],
#  [1, 26, 614, 130, 116, 2, 7, 15, 8],
#  [1, 26, 614, 130, 116, 2, 53],
#  [1, 26, 614, 130, 116, 2, 96],
#  [1, 26, 614, 130, 116],
#  [1, 26, 614, 130, 116, 2, 7, 15, 32],
#  [1, 26, 614, 130, 116, 2, 96],
#  [1, 26, 614, 130, 116]]

# %%
y_train[:10]
# Out:
# [[2, 1, 3, 1, 1, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1],
#  [2, 1, 3, 1, 1],
#  [2, 1, 3, 1, 1, 1, 1, 1, 1]]

# %%
index_to_ner  # 0 : 'PAD' 가 추가되었다.
# Out:
# {1: 'O', 2: 'B_account', 3: 'B_money', 0: 'PAD'}

# %%
# ⑤ 시퀀스 패딩 처리
# max_len = max(len(l) for l in sentences)
max_len = 10  #25
x_train = preprocessing.sequence.pad_sequences(x_train, padding='post', maxlen=max_len)
y_train = preprocessing.sequence.pad_sequences(y_train, padding='post', maxlen=max_len)

# %%
print(x_train.shape)
x_train
print(y_train.shape)
y_train
# Out:
# (105, 10)
# (105, 10)
# array([[2, 1, 3, ..., 1, 1, 0],
#        [2, 1, 3, ..., 1, 1, 0],
#        [2, 1, 3, ..., 0, 0, 0],
#        ...,
#        [2, 1, 3, ..., 0, 0, 0],
#        [2, 1, 3, ..., 0, 0, 0],
#        [2, 1, 3, ..., 0, 0, 0]])

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
from chatbot.utils.Preprocess import Preprocess
import os

# %%
# ⑥ 학습 데이터와 테스트 데이터를 8:2의 비율로 분리
# ★ 한번만 실행하기 ★
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train,
                                                    test_size=.2,
                                                    random_state=1234)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((84, 10), (21, 10), (84, 10), (21, 10))

# %%
x_train
# Out:
# array([[  1,  26, 614, 130, 116,   2,   7,  15,  32,   0],
#        [  1,  26,   1, 130, 116, 216, 374,   8,   0,   0],
#        [  1,  26, 613, 130, 116,   2,   7,  15,   8,   0],
#        [  1,  26,   1, 130, 116,   2,   7,  15,   8,   0],
#        [  1,  26,   1, 130, 116,   2,  53,   0,   0,   0],
#        [  1,  26, 613, 130, 116,   2,   7,  15,  32,   0],
#        [  1,  26, 614, 130, 116, 216, 374,   8,   0,   0],
#        [  1,  26,   1, 130, 116,   0,   0,   0,   0,   0],
#        [  1,  26, 616, 130, 116,   2,   7,  15,  32,   0],
#        [  1,  26,   1, 130, 116,   2,  96,   0,   0,   0],
#        [  1,  26,   1, 130, 116,   0,   0,   0,   0,   0],
#        [  1,  26,   1, 130, 116,   2,  96,   0,   0,   0],
#        [  1,  26, 615, 130, 116,   2,   7,  15,  32,   0],
#        [  1,  26,   1, 130, 116,   2,   7,  15,   8,   0],
#        [  1,  26, 613, 130, 116,   0,   0,   0,   0,   0],
#        [  1,  26,   1, 130, 116, 216, 374,   8,   0,   0],
# ...

# %%
# 출력 데이터를 one-hot encoding
# ★ 한번만 실행할것!
y_train = tf.keras.utils.to_categorical(y_train, num_classes=tag_size)  # tag_size. BIO 태그 사전 크기, 
y_test = tf.keras.utils.to_categorical(y_test, num_classes=tag_size)    # 현재 tag_size 는 10 이다

# %%
y_train.shape, y_test.shape  # 10개 자리 벡터로 확장 되었다. 3차원
# Out:
# ((84, 10, 4), (21, 10, 4))

# %%
print("학습 샘플 시퀀스 형상 : ", x_train.shape)
print("학습 샘플 레이블 형상 : ", y_train.shape)
print("테스트 샘플 시퀀스 형상 : ", x_test.shape)
print("테스트 샘플 레이블 형상 : ", y_test.shape)
# Out:
# 학습 샘플 시퀀스 형상 :  (84, 10)
# 학습 샘플 레이블 형상 :  (84, 10, 4)
# 테스트 샘플 시퀀스 형상 :  (21, 10)
# 테스트 샘플 레이블 형상 :  (21, 10, 4)

# %%
# # ⑦ 모델 정의 (Bi-LSTM)
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
# from tensorflow.keras.optimizers import Adam

# model = Sequential()          # 임배딩                                  ★
# model.add(Embedding(input_dim=vocab_size, output_dim=30, input_length=max_len, mask_zero=True))
# # model.add(keras.layers.SimpleRNN(
# #     units=(128,25),         # 순환층 뉴런개수, 
# #     input_shape=(vocab_size, 30), # layer의 입력차원 앞의 샘플의 시쿼스 길이 100 , 뒤의 500은? 단어표현 -> one-hot encoding 된 형태

# #                         #↑ 순환층의 활성화 함수 activation= 값은 디폴트인 tanh 사
# # ))                                     #★
# model.add(Bidirectional(LSTM(200, return_sequences=True, dropout=0.5, recurrent_dropout=0.25)))
# model.add(TimeDistributed(Dense(25, activation='relu')))
# model.add(keras.layers.Dense(4, activation='softmax'))
# model.compile(loss='categorical_crossentropy', optimizer=Adam(0.01), metrics=['accuracy'])

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, Conv1D, GlobalMaxPool1D, concatenate

import os
MAX_SEQ_LEN=10
EMB_SIZE=128
dropout_prob=0.5

input_layer = Input(shape=(MAX_SEQ_LEN,))  # 입려크기
embedding_layer = Embedding(vocab_size, EMB_SIZE, input_length=MAX_SEQ_LEN)(input_layer)
dropout_emb = Dropout(rate=dropout_prob)(embedding_layer)

conv1 = Conv1D(
    filters=128,
    kernel_size=3,
    padding='valid',
    activation=tf.nn.elu)(dropout_emb)
pool1 = GlobalMaxPool1D()(conv1)

conv2 = Conv1D(
    filters=128,
    kernel_size=4,
    padding='valid',
    activation=tf.nn.elu)(dropout_emb)
pool2 = GlobalMaxPool1D()(conv2)

conv3 = Conv1D(
    filters=128,
    kernel_size=5,
    padding='valid',
    activation=tf.nn.elu)(dropout_emb)
pool3 = GlobalMaxPool1D()(conv3)



# 3,4,5gram 이후 합치기
concat = concatenate([pool1, pool2, pool3])


hidden = Dense(128, activation=tf.nn.elu)(concat)
dropout_hidden = Dropout(rate=dropout_prob)(hidden)
logits = Dense(10, name='logits')(dropout_hidden)  # 최종적으로 5가지 의도 클래스를 분류. 결과로 나온 값(logits) 을을 점수(score) 라 부른다
outputs=Embedding(input_dim=vocab_size, output_dim=30, input_length=max_len, mask_zero=True)(logits)
outputs=Bidirectional(LSTM(200, return_sequences=True, dropout=0.50, recurrent_dropout=0.25))(outputs)
outputs=TimeDistributed(Dense(tag_size, activation='softmax'))(outputs)
model = Model(inputs = input_layer, outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer=Adam(0.01), metrics=['accuracy'])


model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 10)]         0           []
#
#  embedding_26 (Embedding)       (None, 10, 128)      535808      ['input_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 10, 128)      0           ['embedding_26[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 8, 128)       49280       ['dropout_6[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 7, 128)       65664       ['dropout_6[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 6, 128)       82048       ['dropout_6[0][0]']
#
#  global_max_pooling1d_9 (Global  (None, 128)         0           ['conv1d_9[0][0]']
#  MaxPooling1D)
#
#  global_max_pooling1d_10 (Globa  (None, 128)         0           ['conv1d_10[0][0]']
#  lMaxPooling1D)
#
# ...

# %%
model.fit(x_train, y_train, batch_size=128, epochs=8)
# Out:
# Epoch 1/8
# WARNING:tensorflow:Gradients do not exist for variables ['embedding_26/embeddings:0', 'conv1d_9/kernel:0', 'conv1d_9/bias:0', 'conv1d_10/kernel:0', 'conv1d_10/bias:0', 'conv1d_11/kernel:0', 'conv1d_11/bias:0', 'dense_29/kernel:0', 'dense_29/bias:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['embedding_26/embeddings:0', 'conv1d_9/kernel:0', 'conv1d_9/bias:0', 'conv1d_10/kernel:0', 'conv1d_10/bias:0', 'conv1d_11/kernel:0', 'conv1d_11/bias:0', 'dense_29/kernel:0', 'dense_29/bias:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 1/1 [==============================] - 20s 20s/step - loss: 1.3815 - accuracy: 0.4726
# Epoch 2/8
# 1/1 [==============================] - 0s 102ms/step - loss: 1.2089 - accuracy: 0.5238
# ...

# %%
model = keras.Sequential()

model.add(keras.layers.SimpleRNN(
    units=8,         # 순환층 뉴런개수, 
    input_shape=(100, 500), # layer의 입력차원 앞의 샘플의 시쿼스 길이 100 , 뒤의 500은? 단어표현 -> one-hot encoding 된 형태

                        #↑ 순환층의 활성화 함수 activation= 값은 디폴트인 tanh 사용
))

# IMDB 는 이진분류 문제 마지막 출력층은 1개 뉴런 + sigmoid 활성화 함수 사용
model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
# 모델 저장
model_file = os.path.join(r'C:\DevRoot\Dropbox\Py03\chatbot project\transaction\ner', 'ner_model.h5')
model.save(model_file)

# %%
# 시퀀스를 NER 태그로 변환
def sequences_to_tag(sequences):  # 예측값을 index_to_ner를 사용하여 태깅 정보로 변경하는 함수.
    result = []
    for sequence in sequences:  # 전체 시퀀스로부터 시퀀스를 하나씩 꺼낸다.
        temp = []
        for pred in sequence:  # 시퀀스로부터 예측값을 하나씩 꺼낸다.
            pred_index = np.argmax(pred)  # 예를 들어 [0, 0, 1, 0 ,0]라면 1의 인덱스인 2를 리턴한다.
            temp.append(index_to_ner[pred_index].replace("PAD", "O"))  # 'PAD'는 'O'로 변경
        result.append(temp)
    return result

# %%
from seqeval.metrics import f1_score, classification_report

# %%
y_predicted = model.predict(x_test)
pred_tags = sequences_to_tag(y_predicted) # 예측된 NER
test_tags = sequences_to_tag(y_test)    # 실제 NER
#print(classification_report(test_tags, pred_tags))

# f1_score() 함수 만으로 f1 score 값만 출력 가능
#print("F1-score: {:.1%}".format(f1_score(test_tags, pred_tags)))


print(pred_tags[0])
print(test_tags[0])

# %% [markdown]
# #---------------------------------------------------

# %%
# 새로운 유형의 문장 NER 예측
def pred_ner(sentence):
    word_to_index = sent_tokenizer.word_index
    new_sentence = sentence.split()
    new_x = []
    for w in new_sentence:
        try:
            new_x.append(word_to_index.get(w,1))
        except KeyError:
            # 모르는 단어의 경우 OOV
            new_x.append(word_to_index['OOV'])

    print("새로운 유형의 시퀀스 : ", new_x)
    new_padded_seqs = preprocessing.sequence.pad_sequences([new_x], padding="post", value=0, maxlen=max_len)

    # NER 예측
    p = model.predict(np.array([new_padded_seqs[0]]))
    p = np.argmax(p, axis=-1) # 예측된 NER 인덱스값 추출
    print("{:10} {:5}".format("단어", "예측된 NER"))
    print("-" * 50)

    for w, pred in zip(new_sentence, p[0]):
        print("{:10} {:5}".format(w, index_to_ner[pred]))

# %%
pred_ner("111111112에 40700원 이체 하고싶어")
# Out:
# 새로운 유형의 시퀀스 :  [1, 1, 3, 1]
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000152908D0F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# 단어         예측된 NER
# --------------------------------------------------
# 111111112에 B_account
# 40700원     O
# 이체         O
# 하고싶어       O

# %%
pred_ner("953746440에 83370원 이체하고싶어")
# Out:
# 새로운 유형의 시퀀스 :  [1, 1, 1]
# 1/1 [==============================] - 0s 41ms/step
# 단어         예측된 NER
# --------------------------------------------------
# 953746440에 B_account
# 83370원     O
# 이체하고싶어     O

# %%
pred_ner("953746440에 83370 원 이체 하 고 싶 어")
# Out:
# 새로운 유형의 시퀀스 :  [1, 1, 2, 3, 6, 7, 8, 9]
# 1/1 [==============================] - 0s 43ms/step
# 단어         예측된 NER
# --------------------------------------------------
# 953746440에 B_account
# 83370      O
# 원          O
# 이체         O
# 하          O
# 고          O
# 싶          O
# 어          PAD

# %%
pred_ner("111111112에")
# Out:
# 새로운 유형의 시퀀스 :  [1]
# 1/1 [==============================] - 0s 53ms/step
# 단어         예측된 NER
# --------------------------------------------------
# 111111112에 B_account

# %%
pred_ner("953746440에")
# Out:
# 새로운 유형의 시퀀스 :  [1]
# 1/1 [==============================] - 0s 54ms/step
# 단어         예측된 NER
# --------------------------------------------------
# 953746440에 B_account
