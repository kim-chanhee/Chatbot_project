# %% [markdown]
# - 자연어 처리에 있어 제일 처음 수행해야 하는 기본적인 과정
# - 전처리 결과와 품질에 따라 후처리및 결과의 성능차이가 커지므로 중요한 (+ 손이 많이 가는) 작업

# %%
# 전처리 모듈은 챗봇 엔진 내에서 자주 사용하기 때문에 클래스로 설계 해 둡니다

from konlpy.tag import Komoran
import pickle
import jpype


class Preprocess:
    def __init__(self, userdic=None):  # 생성자

        # ① 형태소 분석기 초기화
        self.komoran = Komoran(userdic=userdic)  # 사용자 정의 사전 파일의 경로 입력 가능

        # ② 제외할 품사
        # 참조 : https://docs.komoran.kr/firststep/postypes.html
        # 관계언 제거, 기호 제거
        # 어미 제거
        # 접미사 제거
        self.exclusion_tags = [
            'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            'JX', 'JC',
            'SF', 'SP', 'SS', 'SE', 'SO',
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            'XSN', 'XSV', 'XSA'
        ]

    # ③ 형태소 분석기 POS 태거
    #  이렇게 래퍼(wrapper) 를 만들어 두면 나중에 형태소 분석기 종류를 바꾸어도 동작할수 있다. (유지보수 측면 good)
    def pos(self, sentence):
        return self.komoran.pos(sentence)

    # ④ 불용어 제거 후, 필요한 품사 정보만 가져오기
    def get_keywords(self, pos, without_tag=False):
        f = lambda x: x in self.exclusion_tags
        word_list = []
        for p in pos:
            if f(p[1]) is False:
                word_list.append(p if without_tag is False else p[0])
        return word_list
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # 전처리 모듈은 챗봇 엔진 내에서 자주 사용하기 때문에 클래스로 설계 해 둡니다
# ----> 3 from konlpy.tag import Komoran
#       4 import pickle
#       5 import jpype
#
# ModuleNotFoundError: No module named 'konlpy'

# %% [markdown]
# 테스트

# %%
sent = "대출 조회좀해줘"

# %%
p = Preprocess(userdic = r'C:\Users\drago\OneDrive\문서\DevRoot\dataset\chatbot\user_dic.tsv')

# %%
pos = p.pos(sent)
pos
# Out:
# [('대출', 'NNG'),
#  ('조회', 'NNG'),
#  ('좀', 'MAG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('주', 'VX'),
#  ('어', 'EC')]

# %%
# 불용어 제거된 키워드 출력
ret = p.get_keywords(pos, without_tag=False)
ret
# Out:
# [('대출', 'NNG'), ('조회', 'NNG'), ('좀', 'MAG'), ('주', 'VX')]

# %%
ret = p.get_keywords(pos, without_tag=True)
ret
# Out:
# ['대출', '조회', '좀', '주']

# %% [markdown]
# ## 단어 사전 구축 및 시퀀스 생성

# %%
from tensorflow.keras import preprocessing
import pickle
import os
import pandas as pd

# %%
# 말뭉치 데이터 읽어오기
def read_corpus_data(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
    return data


# ① 말뭉치 데이터 가져오기
corpus_data = read_corpus_data(os.path.join(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\intent', 'corpus1.txt'))

# %%
print(len(corpus_data))
corpus_data[:10]
# Out:
# 5682
# [['안넝', '0'],
#  ['ㅇㅏㄴ넝', '0'],
#  ['아ㄴ넝', '0'],
#  ['안ㄴㅓㅇ', '0'],
#  ['안너ㅇ', '0'],
#  ['얀뇽', '0'],
#  ['ㅇㅑㄴㄴㅛㅇ', '0'],
#  ['야ㄴㄴㅛㅇ', '0'],
#  ['얀ㄴㅛㅇ', '0'],
#  ['얀뇨ㅇ', '0']]

# %%
corpus = corpus_data[1:]
corpus
# Out:
# [['ㅇㅏㄴ넝', '0'],
#  ['아ㄴ넝', '0'],
#  ['안ㄴㅓㅇ', '0'],
#  ['안너ㅇ', '0'],
#  ['얀뇽', '0'],
#  ['ㅇㅑㄴㄴㅛㅇ', '0'],
#  ['야ㄴㄴㅛㅇ', '0'],
#  ['얀ㄴㅛㅇ', '0'],
#  ['얀뇨ㅇ', '0'],
#  ['안녕해', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅐ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅐ', '0'],
#  ['안ㄴㅕㅇㅎㅐ', '0'],
#  ['안녀ㅇㅎㅐ', '0'],
#  ['안녕ㅎㅐ', '0'],
#  ['안녕하십니까', '0'],
#  ['ㅇㅏㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲ ㅏ', '0'],
#  ['안녀ㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ', '0'],
#  ['안녕ㅎㅏㅅㅣㅂㄴㅣㄲㅏ', '0'],
#  ['안녕하ㅅㅣㅂㄴㅣㄲㅏ', '0'],
#  ['안녕하시ㅂㄴㅣㄲㅏ', '0'],
#  ['안녕하십ㄴㅣㄲㅏ', '0'],
#  ['안녕하십니ㄲㅏ', '0'],
#  ['안녕하시오', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㅇㅗ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅣㅇㅗ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅣㅇㅗ', '0'],
#  ['안녀ㅇㅎㅏㅅㅣㅇㅗ', '0'],
#  ['안녕ㅎㅏㅅㅣㅇㅗ', '0'],
#  ['안녕하ㅅㅣㅇㅗ', '0'],
#  ['안녕하시ㅇㅗ', '0'],
#  ['안녕이라고 해도되', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['아ㄴㄴㅕㅇㅇㅣㄹㅏㄱ ㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안ㄴㅕㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녀ㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녕ㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녕이ㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녕이라ㄱㅗㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녕이라고ㅎㅐㄷㅗㄷㅗㅣ', '0'],
#  ['안녕이라고해ㄷㅗㄷㅗㅣ', '0'],
#  ['안녕이라고해도ㄷㅗㅣ', '0'],
#  ['안녕이라고해도도ㅣ', '0'],
#  ['안녕이라할게', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['아ㄴㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['안ㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['안녀ㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['안녕ㅇㅣㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['안녕이ㄹㅏㅎㅏㄹㄱㅔ', '0'],
#  ['안녕이라ㅎㅏㄹㄱㅔ', '0'],
#  ['안녕이라하ㄹㄱㅔ', '0'],
#  ['안녕이라할ㄱㅔ', '0'],
#  ['안뇨하세여', '0'],
#  ['ㅇㅏㄴㄴㅛㅎㅏㅅㅔㅇㅕ', '0'],
#  ['아ㄴㄴㅛㅎㅏㅅㅔㅇㅕ', '0'],
#  ['안ㄴㅛㅎㅏㅅㅔ ㅇㅕ', '0'],
#  ['안뇨ㅎㅏㅅㅔㅇㅕ', '0'],
#  ['안뇨하ㅅㅔㅇㅕ', '0'],
#  ['안뇨하세ㅇㅕ', '0'],
#  ['안녕하세요', '0'],
#  ['ㅇㅏ ㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안녀ㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안녕ㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안녕하ㅅㅔㅇㅛ', '0'],
#  ['안녕하세ㅇㅛ', '0'],
#  ['안녀하세요', '0'],
#  ['ㅇㅏㄴㄴㅕㅎㅏㅅㅔㅇㅛ', '0'],
#  ['아ㄴㄴㅕㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안ㄴㅕㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안녀ㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안녀하ㅅㅔㅇㅛ', '0'],
#  ['안녀하세ㅇㅛ', '0'],
#  ['안녕하새요', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅐㅇㅛ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안녀ㅇㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안녕ㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안녕하ㅅㅐㅇㅛ', '0'],
#  ['안녕하새ㅇㅛ', '0'],
#  ['안녀하새요', '0'],
#  ['ㅇㅏㄴㄴㅕㅎㅏㅅㅐㅇㅛ', '0'],
#  ['아ㄴㄴㅕㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안ㄴㅕㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안녀ㅎㅏㅅㅐㅇㅛ', '0'],
#  ['안녀하ㅅㅐㅇㅛ', '0'],
#  ['안뇨하새ㅇㅛ', '0'],
#  ['안녕하시고', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㄱㅗ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅣㄱㅗ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅣㄱㅗ', '0'],
#  ['안녀ㅇㅎㅏㅅㅣㄱㅗ', '0'],
#  ['안녕ㅎㅏㅅㅣㄱㅗ', '0'],
#  ['안녕하ㅅㅣㄱㅗ', '0'],
#  ['안녕하시ㄱㅗ', '0'],
#  ['안녕하쇼', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['안녀ㅇㅎㅏㅅㅛ', '0'],
#  ['안녕ㅎㅏㅅㅛ', '0'],
#  ['안뇽하ㅅㅛ', '0'],
#  ['안녕하슈', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅠ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅠ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅠ', '0'],
#  ['안녀ㅇㅎㅏㅅㅠ', '0'],
#  ['안녕ㅎㅏㅅㅠ', '0'],
#  ['안녕하ㅅㅠ', '0'],
#  ['안녕허슈', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅓㅅㅠ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅓㅅㅠ', '0'],
#  ['안ㄴㅕㅇㅎㅓㅅㅠ', '0'],
#  ['안녀ㅇㅎㅓㅅㅠ', '0'],
#  ['안녕ㅎㅓㅅㅠ', '0'],
#  ['안녕허ㅅㅠ', '0'],
#  ['안늉', '0'],
#  ['ㅇㅏㄴㄴㅠㅇ', '0'],
#  ['아ㄴㄴㅠㅇ', '0'],
#  ['안ㄴㅠㅇ', '0'],
#  ['안뉴ㅇ', '0'],
#  ['안냥하세요', '0'],
#  ['ㅇㅏㄴㄴㅑㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['아ㄴㄴㅑㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안ㄴㅑㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안냐ㅇㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안냥ㅎㅏㅅㅔㅇㅛ', '0'],
#  ['안냥하ㅅㅔㅇㅛ', '0'],
#  ['안냥하세ㅇㅛ', '0'],
#  ['안냥', '0'],
#  ['ㅇㅏㄴㄴㅑㅇ', '0'],
#  ['아ㄴㄴㅑㅇ', '0'],
#  ['안ㄴㅑㅇ', '0'],
#  ['안냐ㅇ', '0'],
#  ['안녕하소', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅗ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅗ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅗ', '0'],
#  ['안녀ㅇㅎㅏㅅㅗ', '0'],
#  ['안녕ㅎㅏㅅㅗ', '0'],
#  ['안녕하ㅅㅗ', '0'],
#  ['안녕하쇼', '0'],
#  ['ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['아ㄴㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['안ㄴㅕㅇㅎㅏㅅㅛ', '0'],
#  ['안녀ㅇㅎㅏㅅㅛ', '0'],
#  ['안녕ㅎㅏㅅㅛ', '0'],
#  ['안녕하ㅅㅛ', '0'],
#  ['하이고요', '0'],
#  ['ㅎㅏㅇㅣㄱㅗㅇㅛ', '0'],
#  ['하ㅇㅣㄱㅗㅇㅛ', '0'],
#  ['하이ㄱㅗㅇㅛ', '0'],
#  ['하이고ㅇㅛ', '0'],
#  ['하이루', '0'],
#  ['ㅎㅏㅇㅣㄹㅜ', '0'],
#  ['하ㅇㅣㄹㅜ', '0'],
#  ['하이ㄹㅜ', '0'],
#  ['하이영', '0'],
#  ['ㅎㅏㅇㅣㅇㅕㅇ', '0'],
#  ['하ㅇㅣㅇㅕㅇ', '0'],
#  ['하이ㅇㅕㅇ', '0'],
#  ['하이', '0'],
#  ['ㅎㅏㅇㅣ', '0'],
#  ['하ㅇㅣ', '0'],
#  ['하이하이', '0'],
#  ['ㅎㅏㅇㅣㅎㅏㅇㅣ', '0'],
#  ['하ㅇㅣㅎㅏㅇㅣ', '0'],
#  ['하이ㅎㅏㅇㅣ', '0'],
#  ['하이하ㅇㅣ', '0'],
#  ['ㅎㅇㅎㅇ', '0'],
#  ['ㅎㅇ', '0'],
#  ['헬로우', '0'],
#  ['ㅎㅔㄹㄹㅗㅇㅜ', '0'],
#  ['헤ㄹㄹㅗㅇㅜ', '0'],
#  ['헬ㄹㅗㅇㅜ', '0'],
#  ['헬로ㅇㅜ', '0'],
#  ['헬로', '0'],
#  ['ㅎㅔㄹㄹㅗ', '0'],
#  ['헤ㄹㄹㅗ', '0'],
#  ['헬ㄹㅗ', '0'],
#  ['할로', '0'],
#  ['ㅎㅏㄹㄹㅗ', '0'],
#  ['하ㄹㄹㅗ', '0'],
#  ['할ㄹㅗ', '0'],
#  ['헤윙', '0'],
#  ['ㅎㅔㅇㅜㅣㅇ', '0'],
#  ['헤ㅇㅜㅣㅇ', '0'],
#  ['헤우ㅣㅇ', '0'],
#  ['헤위ㅇ', '0'],
#  ['하윙', '0'],
#  ['ㅎㅏㅇㅜㅣㅇ', '0'],
#  ['하ㅇㅜㅣㅇ', '0'],
#  ['하우ㅣㅇ', '0'],
#  ['하위ㅇ', '0'],
#  ['해윙', '0'],
#  ['ㅎㅐㅇㅜㅣㅇ', '0'],
#  ['해ㅇㅜㅣㅇ', '0'],
#  ['해우ㅣㅇ', '0'],
#  ['해위ㅇ', '0'],
#  ['핼로우', '0'],
#  ['ㅎㅐㄹㄹㅗㅇㅜ', '0'],
#  ['해ㄹㄹㅗㅇㅜ', '0'],
#  ['핼ㄹㅗㅇㅜ', '0'],
#  ['핼로ㅇㅜ', '0'],
#  ['하이룽', '0'],
#  ['ㅎㅏㅇㅣㄹㅜㅇ', '0'],
#  ['하ㅇㅣㄹㅜㅇ', '0'],
#  ['하이ㄹㅜㅇ', '0'],
#  ['하이루ㅇ', '0'],
#  ['잘부탁해', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅐ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㅎㅐ', '0'],
#  ['잘부ㅌㅏㄱㅎㅐ', '0'],
#  ['잘부타ㄱㅎㅐ', '0'],
#  ['잘부탁ㅎㅐ', '0'],
#  ['잘부탁행', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅐㅇ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㅎㅐㅇ', '0'],
#  ['잘부ㅌㅏㄱㅎㅐㅇ', '0'],
#  ['잘부타ㄱㅎㅐㅇ', '0'],
#  ['잘부탁ㅎㅐㅇ', '0'],
#  ['잘부탁해ㅇ', '0'],
#  ['잘부탁햄', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅁ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅐㅁ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㅎㅐㅁ', '0'],
#  ['잘부ㅌㅏㄱㅎㅐㅁ', '0'],
#  ['잘부타ㄱㅎㅐㅁ', '0'],
#  ['잘부탁ㅎㅐㅁ', '0'],
#  ['잘부탁해ㅁ', '0'],
#  ['잘부탁할게', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ', '0'],
#  ['잘부ㅌㅏㄱㅎㅏㄹㄱㅔ', '0'],
#  ['잘부타ㄱㅎㅏㄹㄱㅔ', '0'],
#  ['잘부탁ㅎㅏㄹㄱㅔ', '0'],
#  ['잘부탁하ㄹㄱㅔ', '0'],
#  ['잘부탁할ㄱㅔ', '0'],
#  ['잘부탁드릴게요', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘부ㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘부타ㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘부탁ㄷㅡㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘부탁드ㄹㅣㄹㄱㅔㅇㅛ', '0'],
#  ['잘부탁드리ㄹㄱㅔㅇㅛ', '0'],
#  ['잘부탁드릴ㄱㅔㅇㅛ', '0'],
#  ['잘부탁드릴게ㅇㅛ', '0'],
#  ['잘부탁해용', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇㅛㅇ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅐㅇㅛㅇ', '0'],
#  ['잘부ㅌㅏㄱㅎㅐㅇㅛㅇ', '0'],
#  ['잘부타ㄱㅎㅐㅇㅛㅇ', '0'],
#  ['잘부탁ㅎㅐㅇㅛㅇ', '0'],
#  ['잘부탁해ㅇㅛㅇ', '0'],
#  ['잘부탁해영', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ', '0'],
#  ['잘부ㅌㅏㄱㅎㅐㅇㅕㅇ', '0'],
#  ['잘부타ㄱㅎㅐㅇㅕㅇ', '0'],
#  ['잘부탁ㅎㅐㅇㅕㅇ', '0'],
#  ['잘부탁해ㅇㅕㅇ', '0'],
#  ['잘부탁해여ㅇ', '0'],
#  ['잘부탁드립니다', '0'],
#  ['ㅈㅏㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['자ㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['잘ㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['잘부ㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['잘부타ㄱㄷㅡㄹㅣㅂㄴㅣㄷ ㅏ', '0'],
#  ['잘부탁ㄷㅡㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['잘부탁드ㄹㅣㅂㄴㅣㄷㅏ', '0'],
#  ['잘부탁드리ㅂㄴㅣㄷㅏ', '0'],
#  ['잘부탁드립ㄴㅣㄷㅏ', '0'],
#  ['잘부탁드립니ㄷㅏ', '0'],
#  ['반가워', '0'],
#  ['ㅂㅏㄴㄱㅏㅇㅜㅓ', '0'],
#  ['바ㄴㄱㅏㅇㅜㅓ', '0'],
#  ['반ㄱㅏㅇㅜㅓ', '0'],
#  ['반가ㅇㅜㅓ', '0'],
#  ['반가우ㅓ', '0'],
#  ['방가루', '0'],
#  ['ㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['바ㅇㄱㅏㄹㅜ', '0'],
#  ['방ㄱㅏㄹㅜ', '0'],
#  ['방가ㄹㅜ', '0'],
#  ['방가방가', '0'],
#  ['ㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['바ㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['방ㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['방가ㅂㅏㅇㄱㅏ', '0'],
#  ['방가바ㅇㄱㅏ', '0'],
#  ['방가방ㄱㅏ', '0'],
#  ['반가워요', '0'],
#  ['ㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['바ㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['반ㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['반가ㅇㅜㅓㅇㅛ', '0'],
#  ['반가우ㅓㅇㅛ', '0'],
#  ['반가워ㅇㅛ', '0'],
#  ['반가웡', '0'],
#  ['ㅂㅏㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['바ㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['반ㄱㅏㅇㅜㅓㅇ', '0'],
#  ['반가ㅇㅜㅓㅇ', '0'],
#  ['반가우ㅓㅇ', '0'],
#  ['반가워ㅇ', '0'],
#  ['반가루', '0'],
#  ['ㅂㅏㄴㄱㅏㄹㅜ', '0'],
#  ['바ㄴㄱㅏㄹㅜ', '0'],
#  ['반ㄱㅏㄹㅜ', '0'],
#  ['반가ㄹㅜ', '0'],
#  ['반갑습니다', '0'],
#  ['ㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['바ㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['반ㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['반가ㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['반갑ㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['반갑스ㅂㄴㅣㄷㅏ', '0'],
#  ['반갑습ㄴㅣㄷㅏ', '0'],
#  ['반갑습니ㄷㅏ', '0'],
#  ['반가워용', '0'],
#  ['ㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['바ㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['반ㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['반가ㅇㅜㅓㅇㅛㅇ', '0'],
#  ['반가우ㅓㅇㅛㅇ', '0'],
#  ['반가워ㅇㅛㅇ', '0'],
#  ['반가워요ㅇ', '0'],
#  ['반가룽', '0'],
#  ['ㅂㅏㄴㄱㅏㄹㅜㅇ', '0'],
#  ['바ㄴㄱㅏㄹㅜㅇ', '0'],
#  ['반ㄱㅏㄹㅜㅇ', '0'],
#  ['반가ㄹㅜㅇ', '0'],
#  ['반가루ㅇ', '0'],
#  ['잘지냈니', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅆㄴㅣ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅆㄴㅣ', '0'],
#  ['잘ㅈㅣㄴㅐㅆㄴㅣ', '0'],
#  ['잘지ㄴㅐㅆㄴㅣ', '0'],
#  ['잘지내ㅆㄴㅣ', '0'],
#  ['잘지냈ㄴㅣ', '0'],
#  ['만나서반가오', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅗ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅗ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅗ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅗ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅇㅗ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅗ', '0'],
#  ['만나서반ㄱㅏㅇㅗ', '0'],
#  ['만나서반가ㅇㅗ', '0'],
#  ['만나서반가워요', '0'],
#  ['ㅁㅏㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['마ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴ ㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반ㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반가ㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반가우ㅓㅇㅛ', '0'],
#  ['만나서반가워ㅇㅛ', '0'],
#  ['만나서반가워', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴ ㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서ㅂㅏㄴㄱ ㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반 ㄱㅏㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반가ㅇㅜㅓㅇㅛ', '0'],
#  ['만나서반가우ㅓㅇㅛ', '0'],
#  ['만나서반가워ㅇㅛ', '0'],
#  ['만나서반가웡', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서ㅂㅏㄴㄱ ㅏㅇㅜㅓㅇ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서반ㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서반가ㅇㅜㅓㅇ', '0'],
#  ['만나서반가우ㅓㅇ', '0'],
#  ['만나서반가워ㅇ', '0'],
#  ['만나서반가워용', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴ ㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ ㅇ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만나서반 ㄱ ㅏㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만나서반가ㅇㅜㅓㅇㅛㅇ', '0'],
#  ['만나서반가우ㅓㅇㅛㅇ', '0'],
#  ['만나서반가워ㅇㅛㅇ', '0'],
#  ['만나서반가워요ㅇ', '0'],
#  ['만나서반가워영', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나서바ㄴㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나서반ㄱㅏㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나서반가ㅇㅜㅓㅇㅕㅇ', '0'],
#  ['만나서반가우ㅓㅇㅕㅇ', '0'],
#  ['만나서반가워ㅇㅕㅇ', '0'],
#  ['만나서반가워여ㅇ', '0'],
#  ['만나서방가루', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['만나ㅅㅓㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['만나서ㅂㅏㅇㄱㅏㄹㅜ', '0'],
#  ['만나서바ㅇㄱㅏㄹㅜ', '0'],
#  ['만나서방ㄱㅏㄹㅜ', '0'],
#  ['만나서방가ㄹㅜ', '0'],
#  ['만나서방가방가', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만나ㅅㅓㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만나서ㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만나서바ㅇㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만나서방ㄱㅏㅂㅏㅇㄱㅏ', '0'],
#  ['만나서방가ㅂㅏㅇㄱㅏ', '0'],
#  ['만나서방가바ㅇㄱㅏ', '0'],
#  ['만나서방가방ㄱㅏ', '0'],
#  ['만나서방가웡', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나ㅅㅓㅂㅏㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서ㅂㅏㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서바ㅇㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서방ㄱㅏㅇㅜㅓㅇ', '0'],
#  ['만나서방가ㅇㅜㅓㅇ', '0'],
#  ['만나서방가우ㅓㅇ', '0'],
#  ['만나서방가워ㅇ', '0'],
#  ['만나서반갑습니다', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나서바ㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나서반ㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나서반가ㅂㅅㅡㅂㄴㅣㄷㅏ', '0'],
#  ['만나서반갑ㅅㅡㅂㄴㅣㄷ ㅏ', '0'],
#  ['만나서반갑스ㅂㄴㅣㄷㅏ', '0'],
#  ['만나서반갑습ㄴㅣㄷㅏ', '0'],
#  ['만나서 반갑습니ㄷㅏ', '0'],
#  ['만나서반갑습니다용', '0'],
#  ['ㅁㅏㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['마ㄴㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만ㄴㅏㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나ㅅㅓㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서ㅂㅏㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서바ㄴㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서반ㄱㅏㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서반가ㅂㅅㅡㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서반갑ㅅㅡㅂㄴㅣㄷ ㅏㅇㅛㅇ', '0'],
#  ['만나서반갑스ㅂㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서반갑습ㄴㅣㄷㅏㅇㅛㅇ', '0'],
#  ['만나서 반갑습니ㄷㅏㅇㅛㅇ', '0'],
#  ['만나서반갑습니다ㅇㅛㅇ', '0'],
#  ['만나서반갑습니다요ㅇ', '0'],
#  ['잘지내지', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅣ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅣ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅣ', '0'],
#  ['잘지ㄴㅐㅈㅣ', '0'],
#  ['잘지내ㅈㅣ', '0'],
#  ['잘지내징', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅣㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅣㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅣㅇ', '0'],
#  ['잘지ㄴㅐㅈㅣㅇ', '0'],
#  ['잘지내ㅈㅣㅇ', '0'],
#  ['잘지내지ㅇ', '0'],
#  ['잘지내종', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['잘지ㄴㅐㅈㅗㅇ', '0'],
#  ['잘지내ㅈㅗㅇ', '0'],
#  ['잘지내조ㅇ', '0'],
#  ['잘지내졍', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅕㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅕㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅕㅇ', '0'],
#  ['잘지ㄴㅐㅈㅕㅇ', '0'],
#  ['잘지내ㅈㅕㅇ', '0'],
#  ['잘지내져ㅇ', '0'],
#  ['잘지내죵', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅛㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅛㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅛㅇ', '0'],
#  ['잘지ㄴㅐㅈㅛㅇ', '0'],
#  ['잘지내ㅈㅛㅇ', '0'],
#  ['잘지내죠ㅇ', '0'],
#  ['잘지내종', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅗㅇ', '0'],
#  ['잘지ㄴㅐㅈㅗㅇ', '0'],
#  ['잘지내ㅈㅗㅇ', '0'],
#  ['잘지내조ㅇ', '0'],
#  ['잘지내정', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅓㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅓㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅓㅇ', '0'],
#  ['잘지ㄴㅐㅈㅓㅇ', '0'],
#  ['잘지내ㅈㅓㅇ', '0'],
#  ['잘지내저ㅇ', '0'],
#  ['잘지내지용', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅣㅇㅛㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅣㅇㅛㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅣㅇㅛㅇ', '0'],
#  ['잘지ㄴㅐㅈㅣㅇㅛㅇ', '0'],
#  ['잘지내ㅈㅣㅇㅛㅇ', '0'],
#  ['잘지내지ㅇㅛㅇ', '0'],
#  ['잘지내지요ㅇ', '0'],
#  ['잘지내지영', '0'],
#  ['ㅈㅏㄹㅈㅣㄴㅐㅈㅣㅇㅕㅇ', '0'],
#  ['자ㄹㅈㅣㄴㅐㅈㅣㅇㅕㅇ', '0'],
#  ['잘ㅈㅣㄴㅐㅈㅣㅇㅕㅇ', '0'],
#  ['잘지ㄴㅐㅈㅣㅇㅕㅇ', '0'],
#  ['잘지내ㅈㅣㅇㅕㅇ', '0'],
#  ['질지내지ㅇㅕㅇ', '0'],
#  ['잘지내지여ㅇ', '0'],
#  ['안녕하숑', '0'],
#  ['안뇽하숑', '0'],
#  ['안농하숑', '0'],
#  ['안넝하숑', '0'],
#  ['안눙하세요', '0'],
#  ['안뇽하세용', '0'],
#  ['안눙하세용', '0'],
#  ['안넝하세용', '0'],
#  ['안녕하시우', '0'],
#  ['안녕이요', '0'],
#  ['안녕이용', '0'],
#  ['안녕이여용', '0'],
#  ['안녕이여영', '0'],
#  ['안녕이영여', '0'],
#  ['안녕이여', '0'],
#  ['안녕이오', '0'],
#  ['안녕이고', '0'],
#  ['조회', '1'],
#  ['조회좀', '1'],
#  ['조회점', '1'],
#  ['조회해종', '1'],
#  ['조회할래', '1'],
#  ['조회해', '1'],
#  ['조회좀해조', '1'],
#  ['조회해조', '1'],
#  ['조회하고싶어', '1'],
#  ['조회하고싶은데', '1'],
#  ['조회좀하고싶어', '1'],
#  ['조회점하고싶어', '1'],
#  ['조회해줭', '1'],
#  ['조회해봐라', '1'],
#  ['조회해바', '1'],
#  ['조회해봐', '1'],
#  ['조회좀용', '1'],
#  ['조회점요', '1'],
#  ['조회좀요', '1'],
#  ['조회점요', '1'],
#  ['조회영', '1'],
#  ['조회용', '1'],
#  ['조회만용', '1'],
#  ['조회만', '1'],
#  ['조회할랭', '1'],
#  ['조회하고싶퍼', '1'],
#  ['조회하고싶펑', '1'],
#  ['조회해바라', '1'],
#  ['조회좀해바라', '1'],
#  ['조회하라', '1'],
#  ['조회하라고', '1'],
#  ['조회하고싶어용', '1'],
#  ['조회만해종', '1'],
#  ['조회만해죵', '1'],
#  ['조회고', '1'],
#  ['조회슛', '1'],
#  ['조회혀', '1'],
#  ['조회행', '1'],
#  ['조회할려고', '1'],
#  ['조회하고싶어서', '1'],
#  ['조회점하고싶어서', '1'],
#  ['조회만하고싶어', '1'],
#  ['조회만하고싶어서용', '1'],
#  ['조회만하고싶어서요', '1'],
#  ['조회할려고', '1'],
#  ['조회할라고', '1'],
#  ['조회할라꼬', '1'],
#  ['조회해보고싶어서', '1'],
#  ['조회만요', '1'],
#  ['조회영', '1'],
#  ['조회할려고요', '1'],
#  ['확인', '1'],
#  ['확인만', '1'],
#  ['확인좀', '1'],
#  ['확인점', '1'],
#  ['확인용', '1'],
#  ['확인이용', '1'],
#  ['확인만용', '1'],
#  ['확인좀용', '1'],
#  ['확인점용', '1'],
#  ['확인이영', '1'],
#  ['확인만영', '1'],
#  ['확인좀영', '1'],
#  ['확인점영', '1'],
#  ['확인할래', '1'],
#  ['확인만할래', '1'],
#  ['확인점할래', '1'],
#  ['확인좀할래', '1'],
#  ['확인할까', '1'],
#  ['확인좀할까', '1'],
#  ['확인점할까', '1'],
#  ['확인만할까', '1'],
#  ['확인될까', '1'],
#  ['확인점될까', '1'],
#  ['확인만될까', '1'],
#  ['확인좀될까', '1'],
#  ['확인좀할까용', '1'],
#  ['확인점할까용', '1'],
#  ['확인만할까용', '1'],
#  ['확인될까용', '1'],
#  ['확인점될까용', '1'],
#  ['확인만될까용', '1'],
#  ['확인좀될까용', '1'],
#  ['확인좀할까영', '1'],
#  ['확인점할까영', '1'],
#  ['확인만할까영', '1'],
#  ['확인될까영', '1'],
#  ['확인점될까영', '1'],
#  ['확인만될까영', '1'],
#  ['확인좀될까영', '1'],
#  ['확인하고싶어요', '1'],
#  ['가져와', '1'],
#  ['가져와용', '1'],
#  ['가져와요', '1'],
#  ['가져와영', '1'],
#  ['가져오라고', '1'],
#  ['가져올래', '1'],
#  ['가져와줄랴', '1'],
#  ['가져와줄래', '1'],
#  ['가져와줄랭', '1'],
#  ['가져와줄수있나', '1'],
#  ['가져와줄수있지', '1'],
#  ['가져와줄수있나요', '1'],
#  ['가져와줄수있지요', '1'],
#  ['가져올수있냐', '1'],
#  ['가져올수있냐고', '1'],
#  ['내놔', '1'],
#  ['내놩', '1'],
#  ['보여줘', '1'],
#  ['보여', '1'],
#  ['보여줄수있나', '1'],
#  ['보여줘봐', '1'],
#  ['보여줄래', '1'],
#  ['보여봐', '1'],
#  ['보여봐봐', '1'],
#  ['보여주라고', '1'],
#  ['보여줭', '1'],
#  ['보고밍', '1'],
#  ['보고파', '1'],
#  ['보고싶엉', '1'],
#  ['보고시펑', '1'],
#  ['보고싶다', '1'],
#  ['보고싶어', '1'],
#  ['보자', '1'],
#  ['보자고', '1'],
#  ['보여줘바바', '1'],
#  ['보자고요', '1'],
#  ['보자고용', '1'],
#  ['보자고영', '1'],
#  ['보자보자어디보자', '1'],
#  ['돈좀보자', '1'],
#  ['돈확인', '1'],
#  ['돈얼마나썼나', '1'],
#  ['돈이샌다', '1'],
#  ['돈이줄줄새는거 같다', '1'],
#  ['돈이다 어디갔나', '1'],
#  ['돈이 어디갔지', '1'],
#  ['돈확인점', '1'],
#  ['돈확인만해줘', '1'],
#  ['돈확인만해', '1'],
#  ['돈확인좀', '1'],
#  ['나얼마있냐', '1'],
#  ['나얼마있어', '1'],
#  ['나얼마있서', '1'],
#  ['나얼마있나', '1'],
#  ['나얼마있을까', '1'],
#  ['나얼마나돈이있을까', '1'],
#  ['돈이얼마나있나', '1'],
#  ['어디보자돈좀보자', '1'],
#  ['돈이샌나', '1'],
#  ['돈이새고있는거같아', '1'],
#  ['돈이얼로갔지', '1'],
#  ['돈이어디로갔을까', '1'],
#  ['돈이제대로있나', '1'],
#  ['돈이잘있나', '1'],
#  ['돈이어디있나', '1'],
#  ['돈이얼러갔나', '1'],
#  ['돈이어디갔지', '1'],
#  ['돈찾고싶어', '1'],
#  ['돈찾아줘', '1'],
#  ['돈좀찾아줘', '1'],
#  ['돈점찾아줘', '1'],
#  ['돈을찾아줘', '1'],
#  ['돈을찾고싶어', '1'],
#  ['돈볼래', '1'],
#  ['돈볼래용', '1'],
#  ['돈볼래영', '1'],
#  ['돈볼래융', '1'],
#  ['돈체크', '1'],
#  ['머니', '1'],
#  ['머니확인', '1'],
#  ['머니체크', '1'],
#  ['머니점', '1'],
#  ['머니확인점', '1'],
#  ['머니체크점', '1'],
#  ['머니점요', '1'],
#  ['머니점용', '1'],
#  ['머니점영', '1'],
#  ['머니좀요', '1'],
#  ['머니좀용', '1'],
#  ['머니좀영', '1'],
#  ['머니찾아줘', '1'],
#  ['머니샌다', '1'],
#  ['머니가새고있는거같아', '1'],
#  ['머니가얼로갔지', '1'],
#  ['머니가어디로갔을까', '1'],
#  ['머니가제대로있나', '1'],
#  ['머니가잘있나', '1'],
#  ['머니가어디있나', '1'],
#  ['머니가얼러갔나', '1'],
#  ['머니가어디갔지', '1'],
#  ['머니찾고싶어', '1'],
#  ['머니찾아줘', '1'],
#  ['머니좀찾아줘', '1'],
#  ['머니점찾아줘', '1'],
#  ['머니을찾아줘', '1'],
#  ['머니을찾고싶어', '1'],
#  ['머니볼래', '1'],
#  ['머니볼래용', '1'],
#  ['머니볼래영', '1'],
#  ['머니볼래융', '1'],
#  ['적금', '1'],
#  ['적금하는법', '1'],
#  ['적금하고싶어', '1'],
#  ['적금하고싶엉', '1'],
#  ['적금하고싶어용', '1'],
#  ['적금하고싶어요', '1'],
#  ['돈모을래', '1'],
#  ['돈모으고싶어', '1'],
#  ['돈쌓고싶어', '1'],
#  ['돈창고', '1'],
#  ['돈저장', '1'],
#  ['돈저장고', '1'],
#  ['돈저장할랴', '1'],
#  ['돈저장할래', '1'],
#  ['돈저장할랭', '1'],
#  ['돈저장할고싶어', '1'],
#  ['돈저장하고싶어', '1'],
#  ['돈저장하고싶엉', '1'],
#  ['돈저장하고싶어용', '1'],
#  ['돈저장하고싶어영', '1'],
#  ['적금할래', '1'],
#  ['돈모을래', '1'],
#  ['돈모으고싶어', '1'],
#  ['돈모으고싶엉', '1'],
#  ['돈모으고싶어용', '1'],
#  ['돈모으고싶어영', '1'],
#  ['돈모으고싶다', '1'],
#  ['돈모으고싶당', '1'],
#  ['부자되고싶어', '1'],
#  ['부자', '1'],
#  ['부자되는법', '1'],
#  ['부자될래', '1'],
#  ['부자하고싶어', '1'],
#  ['부자할래', '1'],
#  ['부자좀되자', '1'],
#  ['부자되는방법좀', '1'],
#  ['부자되는방법좀요', '1'],
#  ['부자되는방법좀용', '1'],
#  ['부자되는방법좀영', '1'],
#  ['부자되는방법좀영', '1'],
#  ['계좌조회 하고싶엉', '1'],
#  ['계좌조회 하고시퍼', '1'],
#  ['계좌조회 해주게', '1'],
#  ['계좌조회 해주싶쇼', '1'],
#  ['계좌조회 해주고', '1'],
#  ['계계좌조회 제발', '1'],
#  ['계좌조회 해주면', '1'],
#  ['계좌조회는?', '1'],
#  ['계좌조회 하고싶아', '1'],
#  ['계좌조회 하고십어', '1'],
#  ['계좌조회 하고십아', '1'],
#  ['계좌조회 하고십오', '1'],
#  ['계좌조회 하고', '1'],
#  ['계좌조회 해고', '1'],
#  ['계좌조회 하구', '1'],
#  ['계좌조회 하고싶니', '1'],
#  ['계좌조회 하고싶나', '1'],
#  ['계좌조회 하고싶노', '1'],
#  ['계좌조회 하고싶내', '1'],
#  ['계좌조회 하고싶네', '1'],
#  ['계좌조회 하고싶누', '1'],
#  ['계좌조회 하고싶뉘', '1'],
#  ['계좌조회 하고십어', '1'],
#  ['계좌조회 하고십아', '1'],
#  ['계좌조회 하고십우', '1'],
#  ['계좌조회 하고십오', '1'],
#  ['계좌조회 하고십니', '1'],
#  ['계좌조회 하고십나', '1'],
#  ['계좌조회 하고십누', '1'],
#  ['계좌조회 하고십노', '1'],
#  ['계좌조회 하고십파', '1'],
#  ['계좌조회', '1'],
#  ['계좌조회 혜구싶어', '1'],
#  ['계좌조회 하고싶이', '1'],
#  ['계좌조회 하고싶시', '1'],
#  ['계좌조회 해구싶엉', '1'],
#  ['계좌대포좀 하고싶엉', '1'],
#  ['계좌대포 하고시퍼', '1'],
#  ['계좌대포 해주게', '1'],
#  ['계좌대포좀 해주싶쇼', '1'],
#  ['계좌조회좀 해주고', '1'],
#  ['계계좌조회좀 제발', '1'],
#  ['계좌조회좀 해주면', '1'],
#  ['계좌조회좀', '1'],
#  ['계좌조회좀 하고싶아', '1'],
#  ['계좌조회좀 하고십어', '1'],
#  ['계좌조회좀 하고십아', '1'],
#  ['계좌조회좀 하고십오', '1'],
#  ['계좌조회좀 하고', '1'],
#  ['계좌조회좀 해고', '1'],
#  ['계좌조회좀 하구', '1'],
#  ['계좌조회좀 하고싶니', '1'],
#  ['계좌조회좀 하고싶나', '1'],
#  ['계좌조회좀 하고싶노', '1'],
#  ['계좌조회좀 하고싶내', '1'],
#  ['계좌조회좀 하고싶네', '1'],
#  ['계좌조회좀 하고싶누', '1'],
#  ['계좌조회좀 하고싶뉘', '1'],
#  ['계좌조회좀 하고십어', '1'],
#  ['계좌조회좀 하고십아', '1'],
#  ['계좌조회좀 하고십우', '1'],
#  ['계좌조회좀 하고십오', '1'],
#  ['계좌조회좀 하고십니', '1'],
#  ['계좌조회좀 하고십나', '1'],
#  ['계좌조회좀 하고십누', '1'],
#  ['계좌조회좀 하고십노', '1'],
#  ['계좌조회좀 하고십파', '1'],
#  ['계좌조회좀', '1'],
#  ['계좌조회좀 하고싶나?', '1'],
#  ['계좌조회좀 혜구싶어', '1'],
#  ['계좌조회좀 하고싶이', '1'],
#  ['계좌조회좀 하고싶시', '1'],
#  ['계좌조회좀 해구싶엉', '1'],
#  ['계좌조회좀', '1'],
#  ['계좌조회점', '1'],
#  ['계좌조회해종', '1'],
#  ['계좌조회할래', '1'],
#  ['계좌조회해', '1'],
#  ['계좌조회좀해조', '1'],
#  ['계좌조회해조', '1'],
#  ['계좌조회하고싶어', '1'],
#  ['계좌조회하고싶은데', '1'],
#  ['계좌조회좀하고싶어', '1'],
#  ['계좌조회점하고싶어', '1'],
#  ['계좌조회해줭', '1'],
#  ['계좌조회해봐라', '1'],
#  ['계좌조회해바', '1'],
#  ['계좌조회해봐', '1'],
#  ['계좌조회좀용', '1'],
#  ['계좌조회점요', '1'],
#  ['계좌조회좀요', '1'],
#  ['계좌조회점요', '1'],
#  ['계좌조회영', '1'],
#  ['계좌조회용', '1'],
#  ['계좌조회만용', '1'],
#  ['계좌조회만', '1'],
#  ['계좌조회할랭', '1'],
#  ['계좌조회하고싶퍼', '1'],
#  ['계좌조회하고싶펑', '1'],
#  ['계좌조회해바라', '1'],
#  ['계좌조회좀해바라', '1'],
#  ['계좌조회하라', '1'],
#  ['계좌조회하라고', '1'],
#  ['계좌조회하고싶어용', '1'],
#  ['계좌조회만해종', '1'],
#  ['계좌조회만해죵', '1'],
#  ['계좌조회고', '1'],
#  ['계좌조회슛', '1'],
#  ['계좌조회혀', '1'],
#  ['계좌조회행', '1'],
#  ['계좌조회할려고', '1'],
#  ['계좌조회하고싶어서', '1'],
#  ['계좌조회점하고싶어서', '1'],
#  ['계좌조회만하고싶어', '1'],
#  ['계좌조회만하고싶어서용', '1'],
#  ['계좌조회만하고싶어서요', '1'],
#  ['계좌조회할려고', '1'],
#  ['계좌조회할라고', '1'],
#  ['계좌조회할라꼬', '1'],
#  ['계좌조회해보고싶어서', '1'],
#  ['계좌조회만요', '1'],
#  ['계좌조회영', '1'],
#  ['계좌조회할려고요', '1'],
#  ['계좌확인', '1'],
#  ['계좌확인만', '1'],
#  ['계좌확인좀', '1'],
#  ['계좌확인점', '1'],
#  ['계좌확인용', '1'],
#  ['계좌확인이용', '1'],
#  ['계좌확인만용', '1'],
#  ['계좌확인좀용', '1'],
#  ['계좌확인점용', '1'],
#  ['계좌확인이영', '1'],
#  ['계좌확인만영', '1'],
#  ['계좌확인좀영', '1'],
#  ['계좌확인점영', '1'],
#  ['계좌확인할래', '1'],
#  ['계좌확인만할래', '1'],
#  ['계좌확인점할래', '1'],
#  ['계좌확인좀할래', '1'],
#  ['계좌확인할까', '1'],
#  ['계좌확인좀할까', '1'],
#  ['계좌확인점할까', '1'],
#  ['계좌확인만할까', '1'],
#  ['계좌확인될까', '1'],
#  ['계좌확인점될까', '1'],
#  ['계좌확인만될까', '1'],
#  ['계좌확인좀될까', '1'],
#  ['계좌확인좀할까용', '1'],
#  ['계좌확인점할까용', '1'],
#  ['계좌확인만할까용', '1'],
#  ['계좌확인될까용', '1'],
#  ['계좌확인점될까용', '1'],
#  ['계좌확인만될까용', '1'],
#  ['계좌확인좀될까용', '1'],
#  ['계좌확인좀할까영', '1'],
#  ['계좌확인점할까영', '1'],
#  ['계좌확인만할까영', '1'],
#  ['계좌확인될까영', '1'],
#  ['계좌확인점될까영', '1'],
#  ['계좌확인만될까영', '1'],
#  ['계좌확인좀될까영', '1'],
#  ['계좌확인하고싶어요', '1'],
#  ['계좌가져와', '1'],
#  ['계좌가져와용', '1'],
#  ['계좌가져와요', '1'],
#  ['계좌가져와영', '1'],
#  ['계좌가져오라고', '1'],
#  ['계좌가져올래', '1'],
#  ['계좌가져와줄랴', '1'],
#  ['계좌가져와줄래', '1'],
#  ['계좌가져와줄랭', '1'],
#  ['계좌가져와줄수있나', '1'],
#  ['계좌가져와줄수있지', '1'],
#  ['계좌가져와줄수있나요', '1'],
#  ['계좌가져와줄수있지요', '1'],
#  ['계좌가져올수있냐', '1'],
#  ['계좌가져올수있냐고', '1'],
#  ['계좌내놔', '1'],
#  ['계좌내놩', '1'],
#  ['계좌보여줘', '1'],
#  ['계좌보여', '1'],
#  ['계좌보여줄수있나', '1'],
#  ['계좌보여줘봐', '1'],
#  ['계좌보여줄래', '1'],
#  ['계좌보여봐', '1'],
#  ['계좌보여봐봐', '1'],
#  ['계좌보여주라고', '1'],
#  ['계좌보여줭', '1'],
#  ['계좌보고밍', '1'],
#  ['계좌보고파', '1'],
#  ['계좌보고싶엉', '1'],
#  ['계좌보고시펑', '1'],
#  ['계좌보고싶다', '1'],
#  ['계좌보고싶어', '1'],
#  ['계좌보자', '1'],
#  ['계좌보자고', '1'],
#  ['계좌보여줘바바', '1'],
#  ['계좌보자고요', '1'],
#  ['계좌보자고용', '1'],
#  ['계좌보자고영', '1'],
#  ['계좌보자보자어디보자', '1'],
#  ...]

# %%
# ② 위에서 불러온 말뭉치 데이터 리스트에서 문장을 하나씩 불러와 POS 테깅  (★시간걸림★)
p = Preprocess()
dic = []
for c in corpus:
    li = []
    li = c[0].split(',')
    dic.append(li[0])


for i in dic:
    pos = p.pos(i)
pos
# Out:
# [('분실', 'NNG'),
#  ('정보', 'NNG'),
#  ('보', 'VV'),
#  ('자', 'EC'),
#  ('보', 'VX'),
#  ('자', 'EC'),
#  ('어디', 'NP'),
#  ('보', 'VV'),
#  ('자', 'EC')]

# %%
print(len(dic))
dic[:20]
# Out:
# 5681
# ['ㅇㅏㄴ넝',
#  '아ㄴ넝',
#  '안ㄴㅓㅇ',
#  '안너ㅇ',
#  '얀뇽',
#  'ㅇㅑㄴㄴㅛㅇ',
#  '야ㄴㄴㅛㅇ',
#  '얀ㄴㅛㅇ',
#  '얀뇨ㅇ',
#  '안녕해',
#  'ㅇㅏㄴㄴㅕㅇㅎㅐ',
#  '아ㄴㄴㅕㅇㅎㅐ',
#  '안ㄴㅕㅇㅎㅐ',
#  '안녀ㅇㅎㅐ',
#  '안녕ㅎㅐ',
#  '안녕하십니까',
#  'ㅇㅏㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ',
#  '아ㄴㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ',
#  '안ㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲ ㅏ',
#  '안녀ㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ']

# %%
# 테스트 과정에서 우리가 사용한 단어가 사전에 존재하지 않을 수 있습니다. 
# 이 경우 챗봇 엔진에서는 OOV(Out-Of-Vocabulary) 처리를 하지만
# 품질 향상을 위해 단어 사전을 업데이트 하는 것이 좋습니다.  corpus.txt 파일에 해당 단어를 사용하는 말뭉치를 업데이트하여 
# 다시 단어 사전을 생성해주면 됩니다.
# 단어 사전을 만드는데 시간이 꽤 오래 걸립니다.   말뭉치 데이터를 추가할때 데이터 양식에 맞지 않으면 오류가 날수 있으니
# 반드시 \t 를 사용해 데이터를 컬럼에 맞게 추가해야 합니다

# %%
#  ③ Tokenizer 를 이용해 위에서 만든 dict 를 단어 인덱스 딕셔너리 (word_index) 데이터로 만듭니다
# 사전의 첫번 째 인덱스에는 OOV 사용
tokenizer = preprocessing.text.Tokenizer(oov_token='OOV')  # 어휘에 없으면 'OOV' 로 token 대체
tokenizer.fit_on_texts(dic)
word_index = tokenizer

# %%
Word_index = tokenizer.word_index
Word_index
# Out:
# {'OOV': 1,
#  '분실조회': 2,
#  '내계좌조회': 3,
#  '대출조회': 4,
#  '내대출조회': 5,
#  '적금조회': 6,
#  '내적금조회': 7,
#  '계좌조회': 8,
#  '분실조회좀': 9,
#  '계좌조회좀': 10,
#  '내계좌조회좀': 11,
#  '대출조회좀': 12,
#  '내대출조회좀': 13,
#  '적금조회좀': 14,
#  '내적금조회좀': 15,
#  '하고십어': 16,
#  '하고십아': 17,
#  '하고십오': 18,
#  '하고싶나': 19,
#  '말': 20,
#  '납부하려면': 21,
#  '하고싶엉': 22,
#  '하고시퍼': 23,
#  '해주게': 24,
#  '해주싶쇼': 25,
#  '해주고': 26,
#  '제발': 27,
#  '해주면': 28,
#  '하고싶아': 29,
#  '하고': 30,
#  '해고': 31,
#  '하구': 32,
#  '하고싶니': 33,
#  '하고싶노': 34,
#  '하고싶내': 35,
#  '하고싶네': 36,
#  '하고싶누': 37,
#  '하고싶뉘': 38,
#  '하고십우': 39,
#  '하고십니': 40,
#  '하고십나': 41,
#  '하고십누': 42,
#  '하고십노': 43,
#  '하고십파': 44,
#  '혜구싶어': 45,
#  '하고싶이': 46,
#  '하고싶시': 47,
#  '해구싶엉': 48,
#  '야돈보내려면': 49,
#  '이르는': 50,
#  '돈보내려면': 51,
#  '돈보네려면': 52,
#  '야돈보네려면': 53,
#  '사람을': 54,
#  '한다': 55,
#  '납부': 56,
#  '야납부할려면': 57,
#  '말로': 58,
#  '뜻으로': 59,
#  '쓰인다': 60,
#  '이체': 61,
#  '어떡해': 62,
#  '어떡해요': 63,
#  '어떻해요': 64,
#  '어떠해요': 65,
#  '어떧해요': 66,
#  '어떨까요': 67,
#  '어찌해요': 68,
#  '어쩔까': 69,
#  '어쩔래': 70,
#  '어쩔라': 71,
#  '납부해': 72,
#  '이': 73,
#  '같은': 74,
#  '납부해줘': 75,
#  '납부해줘잉': 76,
#  '새끼': 77,
#  '속되게': 78,
#  '쓰이는': 79,
#  '수': 80,
#  '뜻의': 81,
#  '비하하는': 82,
#  '뜻하는': 83,
#  '씨발': 84,
#  '욕': 85,
#  '비슷한': 86,
#  '있다': 87,
#  '의': 88,
#  '원래는': 89,
#  '가': 90,
#  '없다': 91,
#  '어떻게해': 92,
#  '도와줄꺼': 93,
#  '도와줘': 94,
#  '하자': 95,
#  '납부할래': 96,
#  '납부할꺼야': 97,
#  '납부는': 98,
#  '납부할랭': 99,
#  '납부할까': 100,
#  '납부할꼬': 101,
#  '납부해라': 102,
#  '납부준비시켜': 103,
#  '납부진행시켜': 104,
#  '납부진행해': 105,
#  '납부진행해줘': 106,
#  '납부진헁': 107,
#  '납부햬': 108,
#  '납부헤': 109,
#  '걸레': 110,
#  '병신': 111,
#  '싸가지': 112,
#  '씹새끼': 113,
#  '좆': 114,
#  '요즘은': 115,
#  '거의': 116,
#  '놈': 117,
#  '와': 118,
#  '어원은': 119,
#  '어떤': 120,
#  '때': 121,
#  '일컫는': 122,
#  '것을': 123,
#  '주로': 124,
#  '및': 125,
#  '없는': 126,
#  '비하발언': 127,
#  '더': 128,
#  '보지': 129,
#  '욕설로': 130,
#  '쓰는': 131,
#  '준말': 132,
#  '분실조회점요': 133,
#  '분실조회영': 134,
#  '분실조회할려고': 135,
#  'ㅏ': 136,
#  '만ㄴㅏㅅㅓㅂㅏㄴ': 137,
#  'ㄱㅏㅇㅜㅓㅇㅛ': 138,
#  '만나ㅅㅓㅂㅏㄴㄱㅏㅇㅜㅓㅇㅛ': 139,
#  '같다': 140,
#  '확인증': 141,
#  '계좌이체': 142,
#  '납부할려면': 143,
#  '납부할려고': 144,
#  '납부할라교': 145,
#  '야납부하겠다니가요': 146,
#  '갈보': 147,
#  '개년': 148,
#  '개새끼': 149,
#  '개소리': 150,
#  '개': 151,
#  '개씹': 152,
#  '니기미': 153,
#  '니미': 154,
#  '니미럴': 155,
#  '또라이': 156,
#  '미췬': 157,
#  '미친': 158,
#  '미친년': 159,
#  '미친놈': 160,
#  '미친새끼': 161,
#  '불알': 162,
#  '븅신': 163,
#  '뻐큐': 164,
#  '쌍놈': 165,
#  '썅': 166,
#  '씨방새': 167,
#  '씨부랄': 168,
#  '씨팔': 169,
#  '씹년': 170,
#  '씹창': 171,
#  '씹': 172,
#  '염병': 173,
#  '잡놈': 174,
#  '좆까': 175,
#  '좆나': 176,
#  '좆밥': 177,
#  '지랄': 178,
#  '창녀': 179,
#  '니': 180,
#  '패드립': 181,
#  '먹는': 182,
#  '다만': 183,
#  '때문에': 184,
#  '있는': 185,
#  '사람이': 186,
#  '거지': 187,
#  '욕이다': 188,
#  '비하': 189,
#  '인해': 190,
#  '파생된': 191,
#  '많이': 192,
#  '년': 193,
#  '애비': 194,
#  '예': 195,
#  '후장': 196,
#  '하는': 197,
#  '니애미': 198,
#  '자위': 199,
#  '는': 200,
#  '과': 201,
#  '형태로': 202,
#  '이게': 203,
#  '란': 204,
#  '매우': 205,
#  '단어': 206,
#  '의미의': 207,
#  '안녕하쇼': 208,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅛ': 209,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅛ': 210,
#  '안ㄴㅕㅇㅎㅏㅅㅛ': 211,
#  '안녀ㅇㅎㅏㅅㅛ': 212,
#  '안녕ㅎㅏㅅㅛ': 213,
#  '반갑습니ㄷㅏ': 214,
#  '만나서바ㄴㄱㅏㅇㅜㅓㅇㅛ': 215,
#  '만나서반가ㅇㅜㅓㅇㅛ': 216,
#  '만나서반가우ㅓㅇㅛ': 217,
#  '만나서반가워ㅇㅛ': 218,
#  '만나서ㅂㅏㄴㄱ': 219,
#  '만나서반': 220,
#  '만나서반갑ㅅㅡㅂㄴㅣㄷ': 221,
#  '만나서': 222,
#  '잘지내종': 223,
#  'ㅈㅏㄹㅈㅣㄴㅐㅈㅗㅇ': 224,
#  '자ㄹㅈㅣㄴㅐㅈㅗㅇ': 225,
#  '잘ㅈㅣㄴㅐㅈㅗㅇ': 226,
#  '잘지ㄴㅐㅈㅗㅇ': 227,
#  '잘지내ㅈㅗㅇ': 228,
#  '잘지내조ㅇ': 229,
#  '조회점요': 230,
#  '조회영': 231,
#  '조회할려고': 232,
#  '머니찾아줘': 233,
#  '돈모을래': 234,
#  '돈모으고싶어': 235,
#  '부자되는방법좀영': 236,
#  '계좌대포좀': 237,
#  '계좌대포': 238,
#  '계좌조회점요': 239,
#  '계좌조회영': 240,
#  '계좌조회할려고': 241,
#  '내계좌대포좀': 242,
#  '내계좌대포': 243,
#  '내계좌조회점요': 244,
#  '내계좌조회영': 245,
#  '내계좌조회할려고': 246,
#  '계좌정보조회점요': 247,
#  '계좌정보조회영': 248,
#  '계좌정보조회할려고': 249,
#  '내계좌정보조회점요': 250,
#  '내계좌정보조회영': 251,
#  '내계좌정보조회할려고': 252,
#  '대출대포좀': 253,
#  '대출대포': 254,
#  '대출조회점요': 255,
#  '대출조회영': 256,
#  '대출조회할려고': 257,
#  '내대출대포좀': 258,
#  '내대출대포': 259,
#  '내대출조회점요': 260,
#  '내대출조회영': 261,
#  '내대출조회할려고': 262,
#  '내대출보고싶다': 263,
#  '내대출보고싶어': 264,
#  '내대출보자': 265,
#  '내대출보자고': 266,
#  '내대출보여줘바바': 267,
#  '내대출보자고요': 268,
#  '내대출보자고용': 269,
#  '내대출보자고영': 270,
#  '내대출보자보자어디보자': 271,
#  '대출정보조회점요': 272,
#  '대출정보조회영': 273,
#  '대출정보조회할려고': 274,
#  '내대출정보조회점요': 275,
#  '내대출정보조회영': 276,
#  '내대출정보조회할려고': 277,
#  '적금대포좀': 278,
#  '적금대포': 279,
#  '적금조회점요': 280,
#  '적금조회영': 281,
#  '적금조회할려고': 282,
#  '내적금대포좀': 283,
#  '내적금대포': 284,
#  '내적금조회점요': 285,
#  '내적금조회영': 286,
#  '내적금조회할려고': 287,
#  '적금정보조회점요': 288,
#  '적금정보조회영': 289,
#  '적금정보조회할려고': 290,
#  '내적금정보조회점요': 291,
#  '내적금정보조회영': 292,
#  '내적금정보조회할려고': 293,
#  '이체는': 294,
#  '가능시간': 295,
#  '돈보내': 296,
#  '돈보낼래': 297,
#  '돈옮길까': 298,
#  '돈보낼려고': 299,
#  '돈보낼라교': 300,
#  '돈보낸다고': 301,
#  '돈보내겠다고': 302,
#  '돈보내겠다니가요': 303,
#  '돈보네': 304,
#  '돈보넬래': 305,
#  '돈보넬려고': 306,
#  '돈보넬라교': 307,
#  '돈보네겠다고': 308,
#  '돈보네겠다니가요': 309,
#  '여': 310,
#  '야돈보내': 311,
#  '야돈보낼래': 312,
#  '야돈옮길래': 313,
#  '야돈옮길까': 314,
#  '야돈보낼려고': 315,
#  '야돈보낼라교': 316,
#  '야돈보내겠다고': 317,
#  '야돈보내겠다니가요': 318,
#  '야돈보내여': 319,
#  '야돈보네': 320,
#  '야돈보넬래': 321,
#  '야돈보넬려고': 322,
#  '야돈보넬라교': 323,
#  '야돈보네겠다고': 324,
#  '야돈보네겠다니가요': 325,
#  '계좌이체는': 326,
#  '납부하자': 327,
#  '납부하고싶어': 328,
#  '납부좀': 329,
#  '납부해줭': 330,
#  '납부혜': 331,
#  '납부할수있어': 332,
#  '납부할라고': 333,
#  '납부할라구': 334,
#  '납부할려구': 335,
#  '납부해줘라': 336,
#  '납부행': 337,
#  '납부해잉': 338,
#  '납부할려고요': 339,
#  '납부할라구요': 340,
#  '납부할려구요': 341,
#  '납부할라고요': 342,
#  '납부한다고요': 343,
#  '납부하겠다고': 344,
#  '납부하겠다니가요': 345,
#  '야납부할수있어': 346,
#  '야납부할라고': 347,
#  '야납부해줘': 348,
#  '야납부할라교': 349,
#  '야납부하겠다고': 350,
#  '야납부하겠다구요': 351,
#  '야납부하겠다니까요': 352,
#  '색스': 353,
#  '개같은': 354,
#  '개놈': 355,
#  '개뇬': 356,
#  '개보지': 357,
#  '개새': 358,
#  '개색기': 359,
#  '개색끼': 360,
#  '개색히': 361,
#  '개세': 362,
#  '개세끼': 363,
#  '개세이': 364,
#  '개쉐': 365,
#  '개쉐리': 366,
#  '개쉐이': 367,
#  '개쉑': 368,
#  '개시키': 369,
#  '개자슥': 370,
#  '개자지': 371,
#  '개좆': 372,
#  '게색기': 373,
#  '게색끼': 374,
#  '냄비': 375,
#  '니미랄': 376,
#  '니어미': 377,
#  '돌아이': 378,
#  '등신': 379,
#  '똘아이': 380,
#  '띠발': 381,
#  '미친넘': 382,
#  '미틴': 383,
#  '뱅신': 384,
#  '벼엉신': 385,
#  '병쉰': 386,
#  '부랄': 387,
#  '빙시': 388,
#  '빙신': 389,
#  '빠가': 390,
#  '빠구리': 391,
#  '빠굴': 392,
#  '빠큐': 393,
#  '새꺄': 394,
#  '새키': 395,
#  '색끼': 396,
#  '세꺄': 397,
#  '세끼': 398,
#  '섹스': 399,
#  '시부랄': 400,
#  '십8': 401,
#  '십새': 402,
#  '십새끼': 403,
#  '십세': 404,
#  '십쉐': 405,
#  '십쉐이': 406,
#  '십쌔': 407,
#  '십창': 408,
#  '십탱': 409,
#  '싶알': 410,
#  '쌉년': 411,
#  '쌍넘': 412,
#  '쌍년': 413,
#  '쌍뇬': 414,
#  '쌔끼': 415,
#  '쌕': 416,
#  '썅년': 417,
#  '썅놈': 418,
#  '썩을년': 419,
#  '썩을놈': 420,
#  '쓰발': 421,
#  '쓰벌': 422,
#  '씨댕': 423,
#  '씨뎅': 424,
#  '씨바': 425,
#  '씨박': 426,
#  '씨방세': 427,
#  '씨벌': 428,
#  '씨봉': 429,
#  '씨봉알': 430,
#  '씨부럴': 431,
#  '씨불': 432,
#  '씨붕': 433,
#  '씨브랄': 434,
#  '씨파': 435,
#  '씨팍': 436,
#  '씨펄': 437,
#  '씹뇬': 438,
#  '씹보지': 439,
#  '씹새': 440,
#  '씹세': 441,
#  '씹쉐': 442,
#  '씹쌔': 443,
#  '씹질': 444,
#  '씹탱': 445,
#  '씹팔': 446,
#  '씹할': 447,
#  '아가리': 448,
#  '양놈': 449,
#  '엄창': 450,
#  '옘병': 451,
#  '왜놈': 452,
#  '잡년': 453,
#  '젖밥': 454,
#  '조까': 455,
#  '조낸': 456,
#  '조또': 457,
#  '조질래': 458,
#  '좀물': 459,
#  '좃까': 460,
#  '좃밥': 461,
#  '쪼다': 462,
#  '호로': 463,
#  '호로새끼': 464,
#  '호로색': 465,
#  '좆같은': 466,
#  '개씨발': 467,
#  '개지랄': 468,
#  '새끼의': 469,
#  '몹시': 470,
#  '무슨': 471,
#  '뜻이냐고': 472,
#  '물으면': 473,
#  '말은': 474,
#  '것이다': 475,
#  '들을': 476,
#  '잘': 477,
#  '사용되지': 478,
#  '않는': 479,
#  '수단으로': 480,
#  '유서깊은': 481,
#  '현재는': 482,
#  '가진': 483,
#  '것': 484,
#  '발언': 485,
#  '전라도': 486,
#  '나쁜': 487,
#  '인터넷에서': 488,
#  '유명해졌다': 489,
#  '욕설': 490,
#  '본래는': 491,
#  '꿩의': 492,
#  '새끼를': 493,
#  '새끼는': 494,
#  '행동이': 495,
#  '원래': 496,
#  '머리가': 497,
#  '그': 498,
#  '뜻과': 499,
#  '에서': 500,
#  '여자를': 501,
#  '비난하는': 502,
#  '틀딱충': 503,
#  '느개비': 504,
#  '느금마': 505,
#  '이란': 506,
#  '뜻이라는': 507,
#  '설이': 508,
#  '보통': 509,
#  '욕으로': 510,
#  '다': 511,
#  '별로': 512,
#  '않지만': 513,
#  '입을': 514,
#  '붙여': 515,
#  '쓰기도': 516,
#  '않는다': 517,
#  '굉장히': 518,
#  '딸딸이': 519,
#  '일본': 520,
#  '아닌': 521,
#  '떨거지': 522,
#  '낮잡아': 523,
#  '떨어지는': 524,
#  '로': 525,
#  '가리키는': 526,
#  '줄인': 527,
#  '할': 528,
#  'ㄹ로': 529,
#  '시작하는': 530,
#  '말하는': 531,
#  '머저리': 532,
#  '병신과': 533,
#  '에': 534,
#  '심한': 535,
#  '제국주의자': 536,
#  '이라는': 537,
#  '변태': 538,
#  '아치': 539,
#  '비꼬는': 540,
#  '븅딱': 541,
#  '을': 542,
#  '일본어로': 543,
#  '용도로': 544,
#  '유방을': 545,
#  '삐꾸': 546,
#  '뜻이다': 547,
#  '사용한다': 548,
#  '가망이': 549,
#  '예의가': 550,
#  '상놈': 551,
#  '사람의': 552,
#  '비칭할': 553,
#  '인생': 554,
#  '젠장': 555,
#  '의미': 556,
#  '우라질': 557,
#  '육시럴': 558,
#  '자지': 559,
#  '마찬가지로': 560,
#  '여기서': 561,
#  '잡': 562,
#  '욕을': 563,
#  '섞어서': 564,
#  '쓸수도': 565,
#  '정박아': 566,
#  '젖': 567,
#  '비속하게': 568,
#  '일반적으로': 569,
#  '좆도': 570,
#  '좆물': 571,
#  '좆대가리': 572,
#  '성교': 573,
#  '또는': 574,
#  '찐따': 575,
#  '극우적인': 576,
#  '아니다': 577,
#  '화냥년': 578,
#  '분실조회점': 579,
#  '분실조회해종': 580,
#  '분실조회할래': 581,
#  '분실조회해': 582,
#  '분실조회좀해조': 583,
#  '분실조회해조': 584,
#  '분실조회하고싶어': 585,
#  '분실조회하고싶은데': 586,
#  '분실조회좀하고싶어': 587,
#  '분실조회점하고싶어': 588,
#  '분실조회해줭': 589,
#  '분실조회해봐라': 590,
#  '분실조회해바': 591,
#  '분실조회해봐': 592,
#  '분실조회좀용': 593,
#  '분실조회좀요': 594,
#  '분실조회용': 595,
#  '분실조회만용': 596,
#  '분실조회만': 597,
#  '분실조회할랭': 598,
#  '분실조회하고싶퍼': 599,
#  '분실조회하고싶펑': 600,
#  '분실조회해바라': 601,
#  '분실조회좀해바라': 602,
#  '분실조회하라': 603,
#  '분실조회하라고': 604,
#  '분실조회하고싶어용': 605,
#  '분실조회만해종': 606,
#  '분실조회만해죵': 607,
#  '분실조회고': 608,
#  '분실조회슛': 609,
#  '분실조회혀': 610,
#  '분실조회행': 611,
#  '분실조회하고싶어서': 612,
#  '분실조회점하고싶어서': 613,
#  '분실조회만하고싶어': 614,
#  '분실조회만하고싶어서용': 615,
#  '분실조회만하고싶어서요': 616,
#  '분실조회할라고': 617,
#  '분실조회할라꼬': 618,
#  '분실조회해보고싶어서': 619,
#  '분실조회만요': 620,
#  '분실조회할려고요': 621,
#  '분실확인': 622,
#  '분실확인만': 623,
#  '분실확인좀': 624,
#  '분실확인점': 625,
#  '분실확인용': 626,
#  '분실확인이용': 627,
#  '분실확인만용': 628,
#  '분실확인좀용': 629,
#  '분실확인점용': 630,
#  '분실확인이영': 631,
#  '분실확인만영': 632,
#  '분실확인좀영': 633,
#  '분실확인점영': 634,
#  '분실확인할래': 635,
#  '분실확인만할래': 636,
#  '분실확인점할래': 637,
#  '분실확인좀할래': 638,
#  '분실확인할까': 639,
#  '분실확인좀할까': 640,
#  '분실확인점할까': 641,
#  '분실확인만할까': 642,
#  '분실확인될까': 643,
#  '분실확인점될까': 644,
#  '분실확인만될까': 645,
#  '분실확인좀될까': 646,
#  '분실확인좀할까용': 647,
#  '분실확인점할까용': 648,
#  '분실확인만할까용': 649,
#  '분실확인될까용': 650,
#  '분실확인점될까용': 651,
#  '분실확인만될까용': 652,
#  '분실확인좀될까용': 653,
#  '분실확인좀할까영': 654,
#  '분실확인점할까영': 655,
#  '분실확인만할까영': 656,
#  '분실확인될까영': 657,
#  '분실확인점될까영': 658,
#  '분실확인만될까영': 659,
#  '분실확인좀될까영': 660,
#  '분실확인하고싶어요': 661,
#  '분실가져와': 662,
#  '분실가져와용': 663,
#  '분실가져와요': 664,
#  '분실가져와영': 665,
#  '분실가져오라고': 666,
#  '분실가져올래': 667,
#  '분실가져와줄랴': 668,
#  '분실가져와줄래': 669,
#  '분실가져와줄랭': 670,
#  '분실가져와줄수있나': 671,
#  '분실가져와줄수있지': 672,
#  '분실가져와줄수있나요': 673,
#  '분실가져와줄수있지요': 674,
#  '분실가져올수있냐': 675,
#  '분실가져올수있냐고': 676,
#  '분실내놔': 677,
#  '분실내놩': 678,
#  '분실보여줘': 679,
#  '분실보여': 680,
#  '분실보여줄수있나': 681,
#  '분실보여줘봐': 682,
#  '분실보여줄래': 683,
#  '분실보여봐': 684,
#  '분실보여봐봐': 685,
#  '분실보여주라고': 686,
#  '분실보여줭': 687,
#  '분실보고밍': 688,
#  '분실보고파': 689,
#  '분실보고싶엉': 690,
#  '분실보고시펑': 691,
#  '분실보고싶다': 692,
#  '분실보고싶어': 693,
#  '분실보자': 694,
#  '분실보자고': 695,
#  '분실보여줘바바': 696,
#  '분실보자고요': 697,
#  '분실보자고용': 698,
#  '분실보자고영': 699,
#  '분실보자보자어디보자': 700,
#  '분실대포좀': 701,
#  '분실대포': 702,
#  '분실정보조회점요': 703,
#  '분실정보조회영': 704,
#  '분실정보조회할려고': 705,
#  'ㅇㅏㄴ넝': 706,
#  '아ㄴ넝': 707,
#  '안ㄴㅓㅇ': 708,
#  '안너ㅇ': 709,
#  '얀뇽': 710,
#  'ㅇㅑㄴㄴㅛㅇ': 711,
#  '야ㄴㄴㅛㅇ': 712,
#  '얀ㄴㅛㅇ': 713,
#  '얀뇨ㅇ': 714,
#  '안녕해': 715,
#  'ㅇㅏㄴㄴㅕㅇㅎㅐ': 716,
#  '아ㄴㄴㅕㅇㅎㅐ': 717,
#  '안ㄴㅕㅇㅎㅐ': 718,
#  '안녀ㅇㅎㅐ': 719,
#  '안녕ㅎㅐ': 720,
#  '안녕하십니까': 721,
#  'ㅇㅏㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 722,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 723,
#  '안ㄴㅕㅇㅎㅏㅅㅣㅂㄴㅣㄲ': 724,
#  '안녀ㅇㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 725,
#  '안녕ㅎㅏㅅㅣㅂㄴㅣㄲㅏ': 726,
#  '안녕하ㅅㅣㅂㄴㅣㄲㅏ': 727,
#  '안녕하시ㅂㄴㅣㄲㅏ': 728,
#  '안녕하십ㄴㅣㄲㅏ': 729,
#  '안녕하십니ㄲㅏ': 730,
#  '안녕하시오': 731,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㅇㅗ': 732,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅣㅇㅗ': 733,
#  '안ㄴㅕㅇㅎㅏㅅㅣㅇㅗ': 734,
#  '안녀ㅇㅎㅏㅅㅣㅇㅗ': 735,
#  '안녕ㅎㅏㅅㅣㅇㅗ': 736,
#  '안녕하ㅅㅣㅇㅗ': 737,
#  '안녕하시ㅇㅗ': 738,
#  '안녕이라고': 739,
#  '해도되': 740,
#  'ㅇㅏㄴㄴㅕㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 741,
#  '아ㄴㄴㅕㅇㅇㅣㄹㅏㄱ': 742,
#  'ㅗㅎㅐㄷㅗㄷㅗㅣ': 743,
#  '안ㄴㅕㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 744,
#  '안녀ㅇㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 745,
#  '안녕ㅇㅣㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 746,
#  '안녕이ㄹㅏㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 747,
#  '안녕이라ㄱㅗㅎㅐㄷㅗㄷㅗㅣ': 748,
#  '안녕이라고ㅎㅐㄷㅗㄷㅗㅣ': 749,
#  '안녕이라고해ㄷㅗㄷㅗㅣ': 750,
#  '안녕이라고해도ㄷㅗㅣ': 751,
#  '안녕이라고해도도ㅣ': 752,
#  '안녕이라할게': 753,
#  'ㅇㅏㄴㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ': 754,
#  '아ㄴㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ': 755,
#  '안ㄴㅕㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ': 756,
#  '안녀ㅇㅇㅣㄹㅏㅎㅏㄹㄱㅔ': 757,
#  '안녕ㅇㅣㄹㅏㅎㅏㄹㄱㅔ': 758,
#  '안녕이ㄹㅏㅎㅏㄹㄱㅔ': 759,
#  '안녕이라ㅎㅏㄹㄱㅔ': 760,
#  '안녕이라하ㄹㄱㅔ': 761,
#  '안녕이라할ㄱㅔ': 762,
#  '안뇨하세여': 763,
#  'ㅇㅏㄴㄴㅛㅎㅏㅅㅔㅇㅕ': 764,
#  '아ㄴㄴㅛㅎㅏㅅㅔㅇㅕ': 765,
#  '안ㄴㅛㅎㅏㅅㅔ': 766,
#  'ㅇㅕ': 767,
#  '안뇨ㅎㅏㅅㅔㅇㅕ': 768,
#  '안뇨하ㅅㅔㅇㅕ': 769,
#  '안뇨하세ㅇㅕ': 770,
#  '안녕하세요': 771,
#  'ㅇㅏ': 772,
#  'ㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 773,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 774,
#  '안ㄴㅕㅇㅎㅏㅅㅔㅇㅛ': 775,
#  '안녀ㅇㅎㅏㅅㅔㅇㅛ': 776,
#  '안녕ㅎㅏㅅㅔㅇㅛ': 777,
#  '안녕하ㅅㅔㅇㅛ': 778,
#  '안녕하세ㅇㅛ': 779,
#  '안녀하세요': 780,
#  'ㅇㅏㄴㄴㅕㅎㅏㅅㅔㅇㅛ': 781,
#  '아ㄴㄴㅕㅎㅏㅅㅔㅇㅛ': 782,
#  '안ㄴㅕㅎㅏㅅㅔㅇㅛ': 783,
#  '안녀ㅎㅏㅅㅔㅇㅛ': 784,
#  '안녀하ㅅㅔㅇㅛ': 785,
#  '안녀하세ㅇㅛ': 786,
#  '안녕하새요': 787,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅐㅇㅛ': 788,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅐㅇㅛ': 789,
#  '안ㄴㅕㅇㅎㅏㅅㅐㅇㅛ': 790,
#  '안녀ㅇㅎㅏㅅㅐㅇㅛ': 791,
#  '안녕ㅎㅏㅅㅐㅇㅛ': 792,
#  '안녕하ㅅㅐㅇㅛ': 793,
#  '안녕하새ㅇㅛ': 794,
#  '안녀하새요': 795,
#  'ㅇㅏㄴㄴㅕㅎㅏㅅㅐㅇㅛ': 796,
#  '아ㄴㄴㅕㅎㅏㅅㅐㅇㅛ': 797,
#  '안ㄴㅕㅎㅏㅅㅐㅇㅛ': 798,
#  '안녀ㅎㅏㅅㅐㅇㅛ': 799,
#  '안녀하ㅅㅐㅇㅛ': 800,
#  '안뇨하새ㅇㅛ': 801,
#  '안녕하시고': 802,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅣㄱㅗ': 803,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅣㄱㅗ': 804,
#  '안ㄴㅕㅇㅎㅏㅅㅣㄱㅗ': 805,
#  '안녀ㅇㅎㅏㅅㅣㄱㅗ': 806,
#  '안녕ㅎㅏㅅㅣㄱㅗ': 807,
#  '안녕하ㅅㅣㄱㅗ': 808,
#  '안녕하시ㄱㅗ': 809,
#  '안뇽하ㅅㅛ': 810,
#  '안녕하슈': 811,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅠ': 812,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅠ': 813,
#  '안ㄴㅕㅇㅎㅏㅅㅠ': 814,
#  '안녀ㅇㅎㅏㅅㅠ': 815,
#  '안녕ㅎㅏㅅㅠ': 816,
#  '안녕하ㅅㅠ': 817,
#  '안녕허슈': 818,
#  'ㅇㅏㄴㄴㅕㅇㅎㅓㅅㅠ': 819,
#  '아ㄴㄴㅕㅇㅎㅓㅅㅠ': 820,
#  '안ㄴㅕㅇㅎㅓㅅㅠ': 821,
#  '안녀ㅇㅎㅓㅅㅠ': 822,
#  '안녕ㅎㅓㅅㅠ': 823,
#  '안녕허ㅅㅠ': 824,
#  '안늉': 825,
#  'ㅇㅏㄴㄴㅠㅇ': 826,
#  '아ㄴㄴㅠㅇ': 827,
#  '안ㄴㅠㅇ': 828,
#  '안뉴ㅇ': 829,
#  '안냥하세요': 830,
#  'ㅇㅏㄴㄴㅑㅇㅎㅏㅅㅔㅇㅛ': 831,
#  '아ㄴㄴㅑㅇㅎㅏㅅㅔㅇㅛ': 832,
#  '안ㄴㅑㅇㅎㅏㅅㅔㅇㅛ': 833,
#  '안냐ㅇㅎㅏㅅㅔㅇㅛ': 834,
#  '안냥ㅎㅏㅅㅔㅇㅛ': 835,
#  '안냥하ㅅㅔㅇㅛ': 836,
#  '안냥하세ㅇㅛ': 837,
#  '안냥': 838,
#  'ㅇㅏㄴㄴㅑㅇ': 839,
#  '아ㄴㄴㅑㅇ': 840,
#  '안ㄴㅑㅇ': 841,
#  '안냐ㅇ': 842,
#  '안녕하소': 843,
#  'ㅇㅏㄴㄴㅕㅇㅎㅏㅅㅗ': 844,
#  '아ㄴㄴㅕㅇㅎㅏㅅㅗ': 845,
#  '안ㄴㅕㅇㅎㅏㅅㅗ': 846,
#  '안녀ㅇㅎㅏㅅㅗ': 847,
#  '안녕ㅎㅏㅅㅗ': 848,
#  '안녕하ㅅㅗ': 849,
#  '안녕하ㅅㅛ': 850,
#  '하이고요': 851,
#  'ㅎㅏㅇㅣㄱㅗㅇㅛ': 852,
#  '하ㅇㅣㄱㅗㅇㅛ': 853,
#  '하이ㄱㅗㅇㅛ': 854,
#  '하이고ㅇㅛ': 855,
#  '하이루': 856,
#  'ㅎㅏㅇㅣㄹㅜ': 857,
#  '하ㅇㅣㄹㅜ': 858,
#  '하이ㄹㅜ': 859,
#  '하이영': 860,
#  'ㅎㅏㅇㅣㅇㅕㅇ': 861,
#  '하ㅇㅣㅇㅕㅇ': 862,
#  '하이ㅇㅕㅇ': 863,
#  '하이': 864,
#  'ㅎㅏㅇㅣ': 865,
#  '하ㅇㅣ': 866,
#  '하이하이': 867,
#  'ㅎㅏㅇㅣㅎㅏㅇㅣ': 868,
#  '하ㅇㅣㅎㅏㅇㅣ': 869,
#  '하이ㅎㅏㅇㅣ': 870,
#  '하이하ㅇㅣ': 871,
#  'ㅎㅇㅎㅇ': 872,
#  'ㅎㅇ': 873,
#  '헬로우': 874,
#  'ㅎㅔㄹㄹㅗㅇㅜ': 875,
#  '헤ㄹㄹㅗㅇㅜ': 876,
#  '헬ㄹㅗㅇㅜ': 877,
#  '헬로ㅇㅜ': 878,
#  '헬로': 879,
#  'ㅎㅔㄹㄹㅗ': 880,
#  '헤ㄹㄹㅗ': 881,
#  '헬ㄹㅗ': 882,
#  '할로': 883,
#  'ㅎㅏㄹㄹㅗ': 884,
#  '하ㄹㄹㅗ': 885,
#  '할ㄹㅗ': 886,
#  '헤윙': 887,
#  'ㅎㅔㅇㅜㅣㅇ': 888,
#  '헤ㅇㅜㅣㅇ': 889,
#  '헤우ㅣㅇ': 890,
#  '헤위ㅇ': 891,
#  '하윙': 892,
#  'ㅎㅏㅇㅜㅣㅇ': 893,
#  '하ㅇㅜㅣㅇ': 894,
#  '하우ㅣㅇ': 895,
#  '하위ㅇ': 896,
#  '해윙': 897,
#  'ㅎㅐㅇㅜㅣㅇ': 898,
#  '해ㅇㅜㅣㅇ': 899,
#  '해우ㅣㅇ': 900,
#  '해위ㅇ': 901,
#  '핼로우': 902,
#  'ㅎㅐㄹㄹㅗㅇㅜ': 903,
#  '해ㄹㄹㅗㅇㅜ': 904,
#  '핼ㄹㅗㅇㅜ': 905,
#  '핼로ㅇㅜ': 906,
#  '하이룽': 907,
#  'ㅎㅏㅇㅣㄹㅜㅇ': 908,
#  '하ㅇㅣㄹㅜㅇ': 909,
#  '하이ㄹㅜㅇ': 910,
#  '하이루ㅇ': 911,
#  '잘부탁해': 912,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐ': 913,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅐ': 914,
#  '잘ㅂㅜㅌㅏㄱㅎㅐ': 915,
#  '잘부ㅌㅏㄱㅎㅐ': 916,
#  '잘부타ㄱㅎㅐ': 917,
#  '잘부탁ㅎㅐ': 918,
#  '잘부탁행': 919,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇ': 920,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅐㅇ': 921,
#  '잘ㅂㅜㅌㅏㄱㅎㅐㅇ': 922,
#  '잘부ㅌㅏㄱㅎㅐㅇ': 923,
#  '잘부타ㄱㅎㅐㅇ': 924,
#  '잘부탁ㅎㅐㅇ': 925,
#  '잘부탁해ㅇ': 926,
#  '잘부탁햄': 927,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅁ': 928,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅐㅁ': 929,
#  '잘ㅂㅜㅌㅏㄱㅎㅐㅁ': 930,
#  '잘부ㅌㅏㄱㅎㅐㅁ': 931,
#  '잘부타ㄱㅎㅐㅁ': 932,
#  '잘부탁ㅎㅐㅁ': 933,
#  '잘부탁해ㅁ': 934,
#  '잘부탁할게': 935,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ': 936,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ': 937,
#  '잘ㅂㅜㅌㅏㄱㅎㅏㄹㄱㅔ': 938,
#  '잘부ㅌㅏㄱㅎㅏㄹㄱㅔ': 939,
#  '잘부타ㄱㅎㅏㄹㄱㅔ': 940,
#  '잘부탁ㅎㅏㄹㄱㅔ': 941,
#  '잘부탁하ㄹㄱㅔ': 942,
#  '잘부탁할ㄱㅔ': 943,
#  '잘부탁드릴게요': 944,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 945,
#  '자ㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 946,
#  '잘ㅂㅜㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 947,
#  '잘부ㅌㅏㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 948,
#  '잘부타ㄱㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 949,
#  '잘부탁ㄷㅡㄹㅣㄹㄱㅔㅇㅛ': 950,
#  '잘부탁드ㄹㅣㄹㄱㅔㅇㅛ': 951,
#  '잘부탁드리ㄹㄱㅔㅇㅛ': 952,
#  '잘부탁드릴ㄱㅔㅇㅛ': 953,
#  '잘부탁드릴게ㅇㅛ': 954,
#  '잘부탁해용': 955,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇㅛㅇ': 956,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅐㅇㅛㅇ': 957,
#  '잘부ㅌㅏㄱㅎㅐㅇㅛㅇ': 958,
#  '잘부타ㄱㅎㅐㅇㅛㅇ': 959,
#  '잘부탁ㅎㅐㅇㅛㅇ': 960,
#  '잘부탁해ㅇㅛㅇ': 961,
#  '잘부탁해영': 962,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ': 963,
#  '자ㄹㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ': 964,
#  '잘ㅂㅜㅌㅏㄱㅎㅐㅇㅕㅇ': 965,
#  '잘부ㅌㅏㄱㅎㅐㅇㅕㅇ': 966,
#  '잘부타ㄱㅎㅐㅇㅕㅇ': 967,
#  '잘부탁ㅎㅐㅇㅕㅇ': 968,
#  '잘부탁해ㅇㅕㅇ': 969,
#  '잘부탁해여ㅇ': 970,
#  '잘부탁드립니다': 971,
#  'ㅈㅏㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 972,
#  '자ㄹㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 973,
#  '잘ㅂㅜㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 974,
#  '잘부ㅌㅏㄱㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 975,
#  '잘부타ㄱㄷㅡㄹㅣㅂㄴㅣㄷ': 976,
#  '잘부탁ㄷㅡㄹㅣㅂㄴㅣㄷㅏ': 977,
#  '잘부탁드ㄹㅣㅂㄴㅣㄷㅏ': 978,
#  '잘부탁드리ㅂㄴㅣㄷㅏ': 979,
#  '잘부탁드립ㄴㅣㄷㅏ': 980,
#  '잘부탁드립니ㄷㅏ': 981,
#  '반가워': 982,
#  'ㅂㅏㄴㄱㅏㅇㅜㅓ': 983,
#  '바ㄴㄱㅏㅇㅜㅓ': 984,
#  '반ㄱㅏㅇㅜㅓ': 985,
#  '반가ㅇㅜㅓ': 986,
#  '반가우ㅓ': 987,
#  '방가루': 988,
#  'ㅂㅏㅇㄱㅏㄹㅜ': 989,
#  '바ㅇㄱㅏㄹㅜ': 990,
#  '방ㄱㅏㄹㅜ': 991,
#  '방가ㄹㅜ': 992,
#  '방가방가': 993,
#  'ㅂㅏㅇㄱㅏㅂㅏㅇㄱㅏ': 994,
#  '바ㅇㄱㅏㅂㅏㅇㄱㅏ': 995,
#  '방ㄱㅏㅂㅏㅇㄱㅏ': 996,
#  '방가ㅂㅏㅇㄱㅏ': 997,
#  '방가바ㅇㄱㅏ': 998,
#  '방가방ㄱㅏ': 999,
#  '반가워요': 1000,
#  ...}

# %%
# ④ 생성된 단어 인덱스 딕셔너리(word_index) 객체를 파일로 저장
f = open(os.path.join(r'C:\DevRoot\Dropbox\Py03\09_chatbot\transaction\intent',"chatbot_dict.bin"), "wb")  # binary 모드에선 encoding 옵션 필요없다
try:
    pickle.dump(Word_index, f)   # 파이썬 객체(인스턴스)를 피클로 저장하기
except Exception as e:
    print(e)
finally:
    f.close()


# pickle.dump로 객체(값)를 저장할 때는 open('james.p', 'wb')와 같이 파일 모드를 'wb'로 지정해야 합니다. 
# b는 바이너리(binary)를 뜻하는데, 
# 바이너리 파일은 컴퓨터가 처리하는 파일 형식
